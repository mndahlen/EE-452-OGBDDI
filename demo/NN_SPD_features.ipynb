# %% [markdown]
# #### Installation

# %%
import torch

def format_pytorch_version(version):
  return version.split('+')[0]

TORCH_version = torch.__version__
TORCH = format_pytorch_version(TORCH_version)

def format_cuda_version(version):
  return 'cu' + version.replace('.', '')

CUDA_version = torch.version.cuda
CUDA = format_cuda_version(CUDA_version)

# !pip install ogb
# !pip install torch-scatter     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse      -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-cluster     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric

# %% [markdown]
# #### Imports

# %%
import torch
from ogb.linkproppred import PygLinkPropPredDataset
import networkx as nx
import numpy as np
from torch.utils.data import DataLoader
from torch_geometric.utils import negative_sampling, to_networkx
from ogb.linkproppred import Evaluator
import torch.nn.functional as F

import pandas as pd

from helpers import *

# %% [markdown]
# #### Load and configure data

# %%
device = "cuda" if torch.cuda.is_available() else 'cpu'

dataset = PygLinkPropPredDataset(name = 'ogbl-ddi') 

split_edge = dataset.get_edge_split()
train_edge, valid_edge, test_edge = split_edge["train"]["edge"], split_edge["valid"]["edge"], split_edge["test"]["edge"]
graph = dataset[0]
edge_index = graph.edge_index.to(device)
nx_graph = to_networkx(graph, to_undirected=True)

# %% [markdown]
# #### Generating SPD features

# %%
# SPD: Matrix with shortest possible distance from all nodes to our anchor nodes
k = 4267
np.random.seed(0)
node_subset = np.random.choice(nx_graph.number_of_nodes(), size=k, replace=False)
spd = get_spd_matrix(G=nx_graph, S=node_subset, max_spd=5)
spd = torch.Tensor(spd).to(device)
node_features = spd

# %% [markdown]
# #### Model setup

# %%
# Predictor params
in_channels = k
hidden_channels = 256
out_channels = 1
num_layers = 5 + 1
dropout = 0.3

# Learning params
lr = 0.003
batch_size = 64 * 1024
num_epochs = 200
eval_steps = 1
run = 0

# %%
def train_NN(predictor, node_features, edge_index, optimizer, batch_size):
    predictor.train()

    total_loss = total_examples = 0
    for perm in DataLoader(range(pos_train_edge.size(0)), batch_size, shuffle=True):
        optimizer.zero_grad()

        # Get positive loss
        edge = pos_train_edge[perm].t()
        feature_0 = node_features[edge[0], :]
        feature_1 = node_features[edge[1], :]
        pos_out = predictor(feature_0, feature_1)
        pos_loss = -torch.log(pos_out + 1e-15).mean()

        # Get negative loss (Sample using torch_geometric.utils.negative_sampling)
        edge = negative_sampling(edge_index, num_nodes=node_features.size(0),
                                 num_neg_samples=perm.size(0), method='dense')
        feature_0 = node_features[edge[0], :]
        feature_1 = node_features[edge[1], :]
        neg_out = predictor(feature_0, feature_1)
        neg_loss = -torch.log(1 - neg_out + 1e-15).mean()

        # Get total loss and gradients
        loss = pos_loss + neg_loss
        loss.backward()

        # Clip gradient (Limit maximum l2 norm of gradients to 1)
        torch.nn.utils.clip_grad_norm_(predictor.parameters(), 1.0)

        optimizer.step()

        # Get total loss
        num_examples = pos_out.size(0)
        total_loss += loss.item() * num_examples
        total_examples += num_examples

    return total_loss / total_examples

@torch.no_grad()
def test_NN(predictor, node_features, split_edge, batch_size, evaluator, device):
    predictor.eval()

    pos_valid_edge = split_edge['valid']['edge'].to(device)
    neg_valid_edge = split_edge['valid']['edge_neg'].to(device)
    pos_test_edge = split_edge['test']['edge'].to(device)
    neg_test_edge = split_edge['test']['edge_neg'].to(device)

    pos_valid_preds = []
    for perm in DataLoader(range(pos_valid_edge.size(0)), batch_size):
        edge = pos_valid_edge[perm].t()
        feature_0 = node_features[edge[0], :]
        feature_1 = node_features[edge[1], :]
        pos_valid_preds += [predictor(feature_0, feature_1).squeeze().cpu()]
    pos_valid_pred = torch.cat(pos_valid_preds, dim=0)

    neg_valid_preds = []
    for perm in DataLoader(range(neg_valid_edge.size(0)), batch_size):
        edge = neg_valid_edge[perm].t()
        feature_0 = node_features[edge[0], :]
        feature_1 = node_features[edge[1], :]
        neg_valid_preds += [predictor(feature_0, feature_1).squeeze().cpu()]
    neg_valid_pred = torch.cat(neg_valid_preds, dim=0)

    pos_test_preds = []
    for perm in DataLoader(range(pos_test_edge.size(0)), batch_size):
        edge = pos_test_edge[perm].t()
        feature_0 = node_features[edge[0], :]
        feature_1 = node_features[edge[1], :]
        pos_test_preds += [predictor(feature_0, feature_1).squeeze().cpu()]
    pos_test_pred = torch.cat(pos_test_preds, dim=0)

    neg_test_preds = []
    for perm in DataLoader(range(neg_test_edge.size(0)), batch_size):
        edge = neg_test_edge[perm].t()
        feature_0 = node_features[edge[0], :]
        feature_1 = node_features[edge[1], :]
        neg_test_preds += [predictor(feature_0, feature_1).squeeze().cpu()]
    neg_test_pred = torch.cat(neg_test_preds, dim=0)

    results = {}
    for K in [20, 50, 100,1000,10000]:
        evaluator.K = K
        valid_hits = evaluator.eval({
            'y_pred_pos': pos_valid_pred,
            'y_pred_neg': neg_valid_pred,
        })[f'hits@{K}']
        test_hits = evaluator.eval({
            'y_pred_pos': pos_test_pred,
            'y_pred_neg': neg_test_pred,
        })[f'hits@{K}']

        results[f'Hits@{K}'] = (valid_hits, test_hits)

    return results

# %% [markdown]
# #### Train model

# %%
# Evaluator
evaluator = Evaluator(name='ogbl-ddi')
loggers = {
    'Hits@20': Logger(1),
    'Hits@50': Logger(1),
    'Hits@100': Logger(1),
    'Hits@1000': Logger(1),
    'Hits@10000': Logger(1)
}

# %%
# Init model 
predictor = LinkPredictor(in_channels, hidden_channels, out_channels,
                          num_layers, dropout).to(device)
predictor.reset_parameters()
optimizer = torch.optim.Adam(list(predictor.parameters()), lr=lr)

# Train
pos_train_edge = train_edge.to(device)

for epoch in range(1, num_epochs + 1):
    loss = train_NN(predictor, node_features, edge_index, optimizer, batch_size)

    # Test
    results = test_NN(predictor, node_features, split_edge, batch_size, evaluator, device)

    # Logging and prints
    for key, result in results.items():
        loggers[key].add_result(run, result)
    for key, result in results.items():
        valid_hits, test_hits = result
        print(key)
        print(f'Run: {run + 1:02d}, '
              f'Epoch: {epoch:02d}, '
              f'Loss: {loss:.4f}, '
              f'Valid: {100 * valid_hits:.2f}%, '
              f'Test: {100 * test_hits:.2f}%')
    print('---')
# Out:
# Hits@20
# Run: 01, Epoch: 01, Loss: 2.3068, Valid: 3.16%, Test: 3.94%
# Hits@50
# Run: 01, Epoch: 01, Loss: 2.3068, Valid: 4.47%, Test: 5.34%
# Hits@100
# Run: 01, Epoch: 01, Loss: 2.3068, Valid: 5.70%, Test: 6.54%
# Hits@1000
# Run: 01, Epoch: 01, Loss: 2.3068, Valid: 15.55%, Test: 15.37%
# Hits@10000
# Run: 01, Epoch: 01, Loss: 2.3068, Valid: 45.92%, Test: 47.09%
# ---
# Hits@20
# Run: 01, Epoch: 02, Loss: 1.2308, Valid: 0.84%, Test: 0.48%
# Hits@50
# Run: 01, Epoch: 02, Loss: 1.2308, Valid: 2.60%, Test: 1.85%
# Hits@100
# Run: 01, Epoch: 02, Loss: 1.2308, Valid: 4.14%, Test: 3.91%
# Hits@1000
# Run: 01, Epoch: 02, Loss: 1.2308, Valid: 14.12%, Test: 12.94%
# Hits@10000
# Run: 01, Epoch: 02, Loss: 1.2308, Valid: 44.06%, Test: 45.41%
# ---
# Hits@20
# Run: 01, Epoch: 03, Loss: 1.1204, Valid: 5.64%, Test: 5.05%
# Hits@50
# Run: 01, Epoch: 03, Loss: 1.1204, Valid: 7.54%, Test: 6.88%
# Hits@100
# Run: 01, Epoch: 03, Loss: 1.1204, Valid: 9.11%, Test: 8.83%
# Hits@1000
# Run: 01, Epoch: 03, Loss: 1.1204, Valid: 22.44%, Test: 20.86%
# Hits@10000
# Run: 01, Epoch: 03, Loss: 1.1204, Valid: 51.39%, Test: 52.39%
# ---
# Hits@20
# Run: 01, Epoch: 04, Loss: 1.0188, Valid: 12.31%, Test: 6.90%
# Hits@50
# Run: 01, Epoch: 04, Loss: 1.0188, Valid: 15.95%, Test: 9.14%
# Hits@100
# Run: 01, Epoch: 04, Loss: 1.0188, Valid: 18.43%, Test: 12.51%
# Hits@1000
# Run: 01, Epoch: 04, Loss: 1.0188, Valid: 31.64%, Test: 26.35%
# Hits@10000
# Run: 01, Epoch: 04, Loss: 1.0188, Valid: 61.69%, Test: 60.99%
# ---
# Hits@20
# Run: 01, Epoch: 05, Loss: 0.9730, Valid: 16.41%, Test: 10.14%
# Hits@50
# Run: 01, Epoch: 05, Loss: 0.9730, Valid: 19.25%, Test: 10.60%
# Hits@100
# Run: 01, Epoch: 05, Loss: 0.9730, Valid: 20.90%, Test: 10.94%
# Hits@1000
# Run: 01, Epoch: 05, Loss: 0.9730, Valid: 29.36%, Test: 24.06%
# Hits@10000
# Run: 01, Epoch: 05, Loss: 0.9730, Valid: 63.38%, Test: 61.10%
# ---
# Hits@20
# Run: 01, Epoch: 06, Loss: 1.0956, Valid: 13.64%, Test: 11.39%
# Hits@50
# Run: 01, Epoch: 06, Loss: 1.0956, Valid: 18.76%, Test: 13.78%
# Hits@100
# Run: 01, Epoch: 06, Loss: 1.0956, Valid: 21.96%, Test: 19.15%
# Hits@1000
# Run: 01, Epoch: 06, Loss: 1.0956, Valid: 36.12%, Test: 36.32%
# Hits@10000
# Run: 01, Epoch: 06, Loss: 1.0956, Valid: 67.44%, Test: 68.76%
# ---
# Hits@20
# Run: 01, Epoch: 07, Loss: 0.9916, Valid: 25.10%, Test: 25.49%
# Hits@50
# Run: 01, Epoch: 07, Loss: 0.9916, Valid: 27.64%, Test: 30.43%
# Hits@100
# Run: 01, Epoch: 07, Loss: 0.9916, Valid: 29.95%, Test: 31.52%
# Hits@1000
# Run: 01, Epoch: 07, Loss: 0.9916, Valid: 44.50%, Test: 39.00%
# Hits@10000
# Run: 01, Epoch: 07, Loss: 0.9916, Valid: 66.98%, Test: 64.98%
# ---
# Hits@20
# Run: 01, Epoch: 08, Loss: 0.9321, Valid: 29.07%, Test: 21.12%
# Hits@50
# Run: 01, Epoch: 08, Loss: 0.9321, Valid: 30.93%, Test: 24.99%
# Hits@100
# Run: 01, Epoch: 08, Loss: 0.9321, Valid: 33.01%, Test: 27.33%
# Hits@1000
# Run: 01, Epoch: 08, Loss: 0.9321, Valid: 42.74%, Test: 36.12%
# Hits@10000
# Run: 01, Epoch: 08, Loss: 0.9321, Valid: 70.89%, Test: 67.12%
# ---
# Hits@20
# Run: 01, Epoch: 09, Loss: 0.9491, Valid: 19.84%, Test: 13.88%
# Hits@50
# Run: 01, Epoch: 09, Loss: 0.9491, Valid: 26.15%, Test: 15.81%
# Hits@100
# Run: 01, Epoch: 09, Loss: 0.9491, Valid: 29.05%, Test: 17.77%
# Hits@1000
# Run: 01, Epoch: 09, Loss: 0.9491, Valid: 41.21%, Test: 30.33%
# Hits@10000
# Run: 01, Epoch: 09, Loss: 0.9491, Valid: 69.65%, Test: 65.19%
# ---
# Hits@20
# Run: 01, Epoch: 10, Loss: 0.9184, Valid: 30.14%, Test: 23.65%
# Hits@50
# Run: 01, Epoch: 10, Loss: 0.9184, Valid: 32.27%, Test: 27.15%
# Hits@100
# Run: 01, Epoch: 10, Loss: 0.9184, Valid: 35.06%, Test: 30.68%
# Hits@1000
# Run: 01, Epoch: 10, Loss: 0.9184, Valid: 48.63%, Test: 42.93%
# Hits@10000
# Run: 01, Epoch: 10, Loss: 0.9184, Valid: 72.47%, Test: 70.03%
# ---
# Hits@20
# Run: 01, Epoch: 11, Loss: 0.8811, Valid: 31.38%, Test: 30.90%
# Hits@50
# Run: 01, Epoch: 11, Loss: 0.8811, Valid: 35.39%, Test: 33.61%
# Hits@100
# Run: 01, Epoch: 11, Loss: 0.8811, Valid: 38.12%, Test: 37.19%
# Hits@1000
# Run: 01, Epoch: 11, Loss: 0.8811, Valid: 49.98%, Test: 47.51%
# Hits@10000
# Run: 01, Epoch: 11, Loss: 0.8811, Valid: 74.13%, Test: 73.02%
# ---
# Hits@20
# Run: 01, Epoch: 12, Loss: 0.8675, Valid: 20.25%, Test: 16.08%
# Hits@50
# Run: 01, Epoch: 12, Loss: 0.8675, Valid: 27.66%, Test: 21.81%
# Hits@100
# Run: 01, Epoch: 12, Loss: 0.8675, Valid: 31.50%, Test: 29.81%
# Hits@1000
# Run: 01, Epoch: 12, Loss: 0.8675, Valid: 49.77%, Test: 45.33%
# Hits@10000
# Run: 01, Epoch: 12, Loss: 0.8675, Valid: 75.02%, Test: 73.29%
# ---
# Hits@20
# Run: 01, Epoch: 13, Loss: 0.8851, Valid: 9.96%, Test: 1.58%
# Hits@50
# Run: 01, Epoch: 13, Loss: 0.8851, Valid: 16.86%, Test: 3.42%
# Hits@100
# Run: 01, Epoch: 13, Loss: 0.8851, Valid: 23.45%, Test: 8.50%
# Hits@1000
# Run: 01, Epoch: 13, Loss: 0.8851, Valid: 45.28%, Test: 38.06%
# Hits@10000
# Run: 01, Epoch: 13, Loss: 0.8851, Valid: 71.88%, Test: 70.01%
# ---
# Hits@20
# Run: 01, Epoch: 14, Loss: 0.8623, Valid: 33.21%, Test: 33.42%
# Hits@50
# Run: 01, Epoch: 14, Loss: 0.8623, Valid: 38.06%, Test: 38.21%
# Hits@100
# Run: 01, Epoch: 14, Loss: 0.8623, Valid: 41.95%, Test: 40.93%
# Hits@1000
# Run: 01, Epoch: 14, Loss: 0.8623, Valid: 52.26%, Test: 48.47%
# Hits@10000
# Run: 01, Epoch: 14, Loss: 0.8623, Valid: 74.86%, Test: 73.95%
# ---
# Hits@20
# Run: 01, Epoch: 15, Loss: 0.8394, Valid: 22.11%, Test: 19.51%
# Hits@50
# Run: 01, Epoch: 15, Loss: 0.8394, Valid: 29.05%, Test: 22.05%
# Hits@100
# Run: 01, Epoch: 15, Loss: 0.8394, Valid: 33.79%, Test: 23.50%
# Hits@1000
# Run: 01, Epoch: 15, Loss: 0.8394, Valid: 45.83%, Test: 43.27%
# Hits@10000
# Run: 01, Epoch: 15, Loss: 0.8394, Valid: 75.09%, Test: 73.63%
# ---
# Hits@20
# Run: 01, Epoch: 16, Loss: 0.8387, Valid: 28.61%, Test: 25.50%
# Hits@50
# Run: 01, Epoch: 16, Loss: 0.8387, Valid: 33.02%, Test: 31.79%
# Hits@100
# Run: 01, Epoch: 16, Loss: 0.8387, Valid: 36.78%, Test: 35.63%
# Hits@1000
# Run: 01, Epoch: 16, Loss: 0.8387, Valid: 51.12%, Test: 46.72%
# Hits@10000
# Run: 01, Epoch: 16, Loss: 0.8387, Valid: 76.39%, Test: 75.14%
# ---
# Hits@20
# Run: 01, Epoch: 17, Loss: 0.8065, Valid: 25.21%, Test: 15.02%
# Hits@50
# Run: 01, Epoch: 17, Loss: 0.8065, Valid: 30.62%, Test: 17.60%
# Hits@100
# Run: 01, Epoch: 17, Loss: 0.8065, Valid: 33.55%, Test: 20.05%
# Hits@1000
# Run: 01, Epoch: 17, Loss: 0.8065, Valid: 45.95%, Test: 43.88%
# Hits@10000
# Run: 01, Epoch: 17, Loss: 0.8065, Valid: 74.91%, Test: 75.06%
# ---
# Hits@20
# Run: 01, Epoch: 18, Loss: 0.8368, Valid: 34.81%, Test: 31.87%
# Hits@50
# Run: 01, Epoch: 18, Loss: 0.8368, Valid: 39.05%, Test: 39.01%
# Hits@100
# Run: 01, Epoch: 18, Loss: 0.8368, Valid: 41.92%, Test: 40.73%
# Hits@1000
# Run: 01, Epoch: 18, Loss: 0.8368, Valid: 53.26%, Test: 48.65%
# Hits@10000
# Run: 01, Epoch: 18, Loss: 0.8368, Valid: 75.89%, Test: 75.22%
# ---
# Hits@20
# Run: 01, Epoch: 19, Loss: 0.8079, Valid: 34.81%, Test: 24.79%
# Hits@50
# Run: 01, Epoch: 19, Loss: 0.8079, Valid: 37.11%, Test: 32.21%
# Hits@100
# Run: 01, Epoch: 19, Loss: 0.8079, Valid: 40.49%, Test: 36.35%
# Hits@1000
# Run: 01, Epoch: 19, Loss: 0.8079, Valid: 53.74%, Test: 48.96%
# Hits@10000
# Run: 01, Epoch: 19, Loss: 0.8079, Valid: 77.24%, Test: 76.13%
# ---
# Hits@20
# Run: 01, Epoch: 20, Loss: 0.8273, Valid: 33.61%, Test: 22.57%
# Hits@50
# Run: 01, Epoch: 20, Loss: 0.8273, Valid: 37.30%, Test: 27.29%
# Hits@100
# Run: 01, Epoch: 20, Loss: 0.8273, Valid: 39.26%, Test: 30.80%
# Hits@1000
# Run: 01, Epoch: 20, Loss: 0.8273, Valid: 52.32%, Test: 47.08%
# Hits@10000
# Run: 01, Epoch: 20, Loss: 0.8273, Valid: 77.77%, Test: 76.62%
# ---
# Hits@20
# Run: 01, Epoch: 21, Loss: 0.7975, Valid: 20.23%, Test: 11.39%
# Hits@50
# Run: 01, Epoch: 21, Loss: 0.7975, Valid: 26.74%, Test: 14.39%
# Hits@100
# Run: 01, Epoch: 21, Loss: 0.7975, Valid: 29.40%, Test: 19.91%
# Hits@1000
# Run: 01, Epoch: 21, Loss: 0.7975, Valid: 47.08%, Test: 46.65%
# Hits@10000
# Run: 01, Epoch: 21, Loss: 0.7975, Valid: 76.06%, Test: 76.33%
# ---
# Hits@20
# Run: 01, Epoch: 22, Loss: 0.7940, Valid: 22.51%, Test: 6.63%
# Hits@50
# Run: 01, Epoch: 22, Loss: 0.7940, Valid: 26.29%, Test: 13.06%
# Hits@100
# Run: 01, Epoch: 22, Loss: 0.7940, Valid: 31.50%, Test: 21.39%
# Hits@1000
# Run: 01, Epoch: 22, Loss: 0.7940, Valid: 52.67%, Test: 48.39%
# Hits@10000
# Run: 01, Epoch: 22, Loss: 0.7940, Valid: 77.66%, Test: 76.77%
# ---
# Hits@20
# Run: 01, Epoch: 23, Loss: 0.8042, Valid: 32.22%, Test: 16.34%
# Hits@50
# Run: 01, Epoch: 23, Loss: 0.8042, Valid: 34.96%, Test: 20.75%
# Hits@100
# Run: 01, Epoch: 23, Loss: 0.8042, Valid: 37.13%, Test: 26.57%
# Hits@1000
# Run: 01, Epoch: 23, Loss: 0.8042, Valid: 52.97%, Test: 49.21%
# Hits@10000
# Run: 01, Epoch: 23, Loss: 0.8042, Valid: 78.65%, Test: 77.44%
# ---
# Hits@20
# Run: 01, Epoch: 24, Loss: 0.7985, Valid: 25.05%, Test: 5.42%
# Hits@50
# Run: 01, Epoch: 24, Loss: 0.7985, Valid: 27.78%, Test: 7.79%
# Hits@100
# Run: 01, Epoch: 24, Loss: 0.7985, Valid: 30.75%, Test: 11.12%
# Hits@1000
# Run: 01, Epoch: 24, Loss: 0.7985, Valid: 45.54%, Test: 38.06%
# Hits@10000
# Run: 01, Epoch: 24, Loss: 0.7985, Valid: 78.77%, Test: 77.61%
# ---
# Hits@20
# Run: 01, Epoch: 25, Loss: 0.7974, Valid: 20.90%, Test: 5.81%
# Hits@50
# Run: 01, Epoch: 25, Loss: 0.7974, Valid: 25.27%, Test: 9.82%
# Hits@100
# Run: 01, Epoch: 25, Loss: 0.7974, Valid: 28.85%, Test: 15.38%
# Hits@1000
# Run: 01, Epoch: 25, Loss: 0.7974, Valid: 49.60%, Test: 40.31%
# Hits@10000
# Run: 01, Epoch: 25, Loss: 0.7974, Valid: 76.97%, Test: 75.38%
# ---
# Hits@20
# Run: 01, Epoch: 26, Loss: 0.7964, Valid: 18.89%, Test: 6.40%
# Hits@50
# Run: 01, Epoch: 26, Loss: 0.7964, Valid: 21.82%, Test: 15.59%
# Hits@100
# Run: 01, Epoch: 26, Loss: 0.7964, Valid: 26.89%, Test: 22.49%
# Hits@1000
# Run: 01, Epoch: 26, Loss: 0.7964, Valid: 52.61%, Test: 48.75%
# Hits@10000
# Run: 01, Epoch: 26, Loss: 0.7964, Valid: 77.34%, Test: 76.60%
# ---
# Hits@20
# Run: 01, Epoch: 27, Loss: 0.7934, Valid: 10.15%, Test: 1.24%
# Hits@50
# Run: 01, Epoch: 27, Loss: 0.7934, Valid: 12.34%, Test: 1.86%
# Hits@100
# Run: 01, Epoch: 27, Loss: 0.7934, Valid: 13.94%, Test: 3.04%
# Hits@1000
# Run: 01, Epoch: 27, Loss: 0.7934, Valid: 26.61%, Test: 21.46%
# Hits@10000
# Run: 01, Epoch: 27, Loss: 0.7934, Valid: 77.05%, Test: 76.73%
# ---
# Hits@20
# Run: 01, Epoch: 28, Loss: 0.7909, Valid: 11.54%, Test: 3.12%
# Hits@50
# Run: 01, Epoch: 28, Loss: 0.7909, Valid: 15.43%, Test: 5.46%
# Hits@100
# Run: 01, Epoch: 28, Loss: 0.7909, Valid: 18.03%, Test: 8.22%
# Hits@1000
# Run: 01, Epoch: 28, Loss: 0.7909, Valid: 44.44%, Test: 46.31%
# Hits@10000
# Run: 01, Epoch: 28, Loss: 0.7909, Valid: 79.49%, Test: 78.92%
# ---
# Hits@20
# Run: 01, Epoch: 29, Loss: 0.7779, Valid: 9.46%, Test: 1.77%
# Hits@50
# Run: 01, Epoch: 29, Loss: 0.7779, Valid: 12.52%, Test: 2.40%
# Hits@100
# Run: 01, Epoch: 29, Loss: 0.7779, Valid: 14.62%, Test: 3.85%
# Hits@1000
# Run: 01, Epoch: 29, Loss: 0.7779, Valid: 31.90%, Test: 27.89%
# Hits@10000
# Run: 01, Epoch: 29, Loss: 0.7779, Valid: 77.87%, Test: 77.52%
# ---
# Hits@20
# Run: 01, Epoch: 30, Loss: 0.7776, Valid: 14.25%, Test: 3.37%
# Hits@50
# Run: 01, Epoch: 30, Loss: 0.7776, Valid: 15.44%, Test: 6.32%
# Hits@100
# Run: 01, Epoch: 30, Loss: 0.7776, Valid: 19.10%, Test: 9.58%
# Hits@1000
# Run: 01, Epoch: 30, Loss: 0.7776, Valid: 38.74%, Test: 38.62%
# Hits@10000
# Run: 01, Epoch: 30, Loss: 0.7776, Valid: 77.88%, Test: 77.57%
# ---
# Hits@20
# Run: 01, Epoch: 31, Loss: 0.7796, Valid: 12.43%, Test: 1.97%
# Hits@50
# Run: 01, Epoch: 31, Loss: 0.7796, Valid: 13.57%, Test: 3.08%
# Hits@100
# Run: 01, Epoch: 31, Loss: 0.7796, Valid: 16.03%, Test: 5.01%
# Hits@1000
# Run: 01, Epoch: 31, Loss: 0.7796, Valid: 33.55%, Test: 30.20%
# Hits@10000
# Run: 01, Epoch: 31, Loss: 0.7796, Valid: 78.37%, Test: 77.99%
# ---
# Hits@20
# Run: 01, Epoch: 32, Loss: 0.7729, Valid: 9.91%, Test: 8.44%
# Hits@50
# Run: 01, Epoch: 32, Loss: 0.7729, Valid: 16.40%, Test: 18.54%
# Hits@100
# Run: 01, Epoch: 32, Loss: 0.7729, Valid: 20.75%, Test: 29.12%
# Hits@1000
# Run: 01, Epoch: 32, Loss: 0.7729, Valid: 52.21%, Test: 49.91%
# Hits@10000
# Run: 01, Epoch: 32, Loss: 0.7729, Valid: 77.60%, Test: 77.60%
# ---
# Hits@20
# Run: 01, Epoch: 33, Loss: 0.8513, Valid: 17.68%, Test: 31.11%
# Hits@50
# Run: 01, Epoch: 33, Loss: 0.8513, Valid: 31.17%, Test: 37.99%
# Hits@100
# Run: 01, Epoch: 33, Loss: 0.8513, Valid: 37.50%, Test: 41.37%
# Hits@1000
# Run: 01, Epoch: 33, Loss: 0.8513, Valid: 51.89%, Test: 50.85%
# Hits@10000
# Run: 01, Epoch: 33, Loss: 0.8513, Valid: 76.96%, Test: 77.96%
# ---
# Hits@20
# Run: 01, Epoch: 34, Loss: 0.8109, Valid: 17.15%, Test: 17.29%
# Hits@50
# Run: 01, Epoch: 34, Loss: 0.8109, Valid: 21.91%, Test: 24.10%
# Hits@100
# Run: 01, Epoch: 34, Loss: 0.8109, Valid: 27.33%, Test: 29.50%
# Hits@1000
# Run: 01, Epoch: 34, Loss: 0.8109, Valid: 48.57%, Test: 49.04%
# Hits@10000
# Run: 01, Epoch: 34, Loss: 0.8109, Valid: 77.08%, Test: 78.18%
# ---
# Hits@20
# Run: 01, Epoch: 35, Loss: 0.8236, Valid: 11.48%, Test: 14.08%
# Hits@50
# Run: 01, Epoch: 35, Loss: 0.8236, Valid: 26.39%, Test: 21.98%
# Hits@100
# Run: 01, Epoch: 35, Loss: 0.8236, Valid: 34.75%, Test: 24.39%
# Hits@1000
# Run: 01, Epoch: 35, Loss: 0.8236, Valid: 50.09%, Test: 38.03%
# Hits@10000
# Run: 01, Epoch: 35, Loss: 0.8236, Valid: 76.62%, Test: 73.49%
# ---
# Hits@20
# Run: 01, Epoch: 36, Loss: 0.8398, Valid: 25.67%, Test: 22.91%
# Hits@50
# Run: 01, Epoch: 36, Loss: 0.8398, Valid: 28.68%, Test: 27.22%
# Hits@100
# Run: 01, Epoch: 36, Loss: 0.8398, Valid: 32.01%, Test: 30.82%
# Hits@1000
# Run: 01, Epoch: 36, Loss: 0.8398, Valid: 49.62%, Test: 48.51%
# Hits@10000
# Run: 01, Epoch: 36, Loss: 0.8398, Valid: 78.49%, Test: 78.06%
# ---
# Hits@20
# Run: 01, Epoch: 37, Loss: 0.8058, Valid: 5.92%, Test: 13.51%
# Hits@50
# Run: 01, Epoch: 37, Loss: 0.8058, Valid: 17.07%, Test: 20.73%
# Hits@100
# Run: 01, Epoch: 37, Loss: 0.8058, Valid: 22.23%, Test: 26.46%
# Hits@1000
# Run: 01, Epoch: 37, Loss: 0.8058, Valid: 49.73%, Test: 45.37%
# Hits@10000
# Run: 01, Epoch: 37, Loss: 0.8058, Valid: 76.90%, Test: 76.42%
# ---
# Hits@20
# Run: 01, Epoch: 38, Loss: 0.8211, Valid: 18.46%, Test: 8.93%
# Hits@50
# Run: 01, Epoch: 38, Loss: 0.8211, Valid: 25.03%, Test: 22.73%
# Hits@100
# Run: 01, Epoch: 38, Loss: 0.8211, Valid: 32.10%, Test: 31.87%
# Hits@1000
# Run: 01, Epoch: 38, Loss: 0.8211, Valid: 54.16%, Test: 52.10%
# Hits@10000
# Run: 01, Epoch: 38, Loss: 0.8211, Valid: 78.93%, Test: 78.71%
# ---
# Hits@20
# Run: 01, Epoch: 39, Loss: 0.7702, Valid: 16.19%, Test: 7.55%
# Hits@50
# Run: 01, Epoch: 39, Loss: 0.7702, Valid: 20.89%, Test: 17.78%
# Hits@100
# Run: 01, Epoch: 39, Loss: 0.7702, Valid: 25.65%, Test: 23.13%
# Hits@1000
# Run: 01, Epoch: 39, Loss: 0.7702, Valid: 52.09%, Test: 50.17%
# Hits@10000
# Run: 01, Epoch: 39, Loss: 0.7702, Valid: 79.11%, Test: 78.54%
# ---
# Hits@20
# Run: 01, Epoch: 40, Loss: 0.7681, Valid: 15.58%, Test: 10.43%
# Hits@50
# Run: 01, Epoch: 40, Loss: 0.7681, Valid: 20.70%, Test: 14.87%
# Hits@100
# Run: 01, Epoch: 40, Loss: 0.7681, Valid: 24.30%, Test: 20.01%
# Hits@1000
# Run: 01, Epoch: 40, Loss: 0.7681, Valid: 48.22%, Test: 48.82%
# Hits@10000
# Run: 01, Epoch: 40, Loss: 0.7681, Valid: 79.51%, Test: 79.34%
# ---
# Hits@20
# Run: 01, Epoch: 41, Loss: 0.7568, Valid: 11.39%, Test: 2.81%
# Hits@50
# Run: 01, Epoch: 41, Loss: 0.7568, Valid: 15.02%, Test: 6.54%
# Hits@100
# Run: 01, Epoch: 41, Loss: 0.7568, Valid: 20.80%, Test: 10.16%
# Hits@1000
# Run: 01, Epoch: 41, Loss: 0.7568, Valid: 45.06%, Test: 47.40%
# Hits@10000
# Run: 01, Epoch: 41, Loss: 0.7568, Valid: 79.31%, Test: 79.04%
# ---
# Hits@20
# Run: 01, Epoch: 42, Loss: 0.7528, Valid: 14.67%, Test: 3.49%
# Hits@50
# Run: 01, Epoch: 42, Loss: 0.7528, Valid: 16.36%, Test: 5.73%
# Hits@100
# Run: 01, Epoch: 42, Loss: 0.7528, Valid: 18.86%, Test: 8.29%
# Hits@1000
# Run: 01, Epoch: 42, Loss: 0.7528, Valid: 38.53%, Test: 36.38%
# Hits@10000
# Run: 01, Epoch: 42, Loss: 0.7528, Valid: 80.01%, Test: 80.02%
# ---
# Hits@20
# Run: 01, Epoch: 43, Loss: 0.7507, Valid: 12.40%, Test: 2.79%
# Hits@50
# Run: 01, Epoch: 43, Loss: 0.7507, Valid: 13.94%, Test: 5.35%
# Hits@100
# Run: 01, Epoch: 43, Loss: 0.7507, Valid: 16.30%, Test: 7.59%
# Hits@1000
# Run: 01, Epoch: 43, Loss: 0.7507, Valid: 33.31%, Test: 32.18%
# Hits@10000
# Run: 01, Epoch: 43, Loss: 0.7507, Valid: 78.98%, Test: 79.38%
# ---
# Hits@20
# Run: 01, Epoch: 44, Loss: 0.7705, Valid: 9.63%, Test: 4.15%
# Hits@50
# Run: 01, Epoch: 44, Loss: 0.7705, Valid: 15.09%, Test: 6.65%
# Hits@100
# Run: 01, Epoch: 44, Loss: 0.7705, Valid: 19.75%, Test: 10.77%
# Hits@1000
# Run: 01, Epoch: 44, Loss: 0.7705, Valid: 41.32%, Test: 37.62%
# Hits@10000
# Run: 01, Epoch: 44, Loss: 0.7705, Valid: 79.66%, Test: 79.97%
# ---
# Hits@20
# Run: 01, Epoch: 45, Loss: 0.7826, Valid: 24.12%, Test: 7.67%
# Hits@50
# Run: 01, Epoch: 45, Loss: 0.7826, Valid: 28.03%, Test: 10.61%
# Hits@100
# Run: 01, Epoch: 45, Loss: 0.7826, Valid: 31.06%, Test: 16.64%
# Hits@1000
# Run: 01, Epoch: 45, Loss: 0.7826, Valid: 48.80%, Test: 42.21%
# Hits@10000
# Run: 01, Epoch: 45, Loss: 0.7826, Valid: 80.64%, Test: 80.04%
# ---
# Hits@20
# Run: 01, Epoch: 46, Loss: 0.7588, Valid: 9.77%, Test: 1.46%
# Hits@50
# Run: 01, Epoch: 46, Loss: 0.7588, Valid: 11.83%, Test: 2.99%
# Hits@100
# Run: 01, Epoch: 46, Loss: 0.7588, Valid: 13.82%, Test: 4.63%
# Hits@1000
# Run: 01, Epoch: 46, Loss: 0.7588, Valid: 38.17%, Test: 37.28%
# Hits@10000
# Run: 01, Epoch: 46, Loss: 0.7588, Valid: 80.66%, Test: 80.71%
# ---
# Hits@20
# Run: 01, Epoch: 47, Loss: 0.7656, Valid: 5.56%, Test: 2.09%
# Hits@50
# Run: 01, Epoch: 47, Loss: 0.7656, Valid: 6.97%, Test: 4.51%
# Hits@100
# Run: 01, Epoch: 47, Loss: 0.7656, Valid: 9.97%, Test: 6.84%
# Hits@1000
# Run: 01, Epoch: 47, Loss: 0.7656, Valid: 33.41%, Test: 40.07%
# Hits@10000
# Run: 01, Epoch: 47, Loss: 0.7656, Valid: 78.17%, Test: 78.88%
# ---
# Hits@20
# Run: 01, Epoch: 48, Loss: 0.7738, Valid: 15.01%, Test: 11.15%
# Hits@50
# Run: 01, Epoch: 48, Loss: 0.7738, Valid: 18.43%, Test: 17.33%
# Hits@100
# Run: 01, Epoch: 48, Loss: 0.7738, Valid: 23.10%, Test: 23.19%
# Hits@1000
# Run: 01, Epoch: 48, Loss: 0.7738, Valid: 54.57%, Test: 51.61%
# Hits@10000
# Run: 01, Epoch: 48, Loss: 0.7738, Valid: 79.22%, Test: 79.36%
# ---
# Hits@20
# Run: 01, Epoch: 49, Loss: 0.7678, Valid: 16.19%, Test: 6.64%
# Hits@50
# Run: 01, Epoch: 49, Loss: 0.7678, Valid: 21.25%, Test: 8.78%
# Hits@100
# Run: 01, Epoch: 49, Loss: 0.7678, Valid: 25.36%, Test: 11.53%
# Hits@1000
# Run: 01, Epoch: 49, Loss: 0.7678, Valid: 45.05%, Test: 43.13%
# Hits@10000
# Run: 01, Epoch: 49, Loss: 0.7678, Valid: 80.40%, Test: 80.46%
# ---
# Hits@20
# Run: 01, Epoch: 50, Loss: 0.7666, Valid: 12.14%, Test: 2.99%
# Hits@50
# Run: 01, Epoch: 50, Loss: 0.7666, Valid: 16.10%, Test: 4.55%
# Hits@100
# Run: 01, Epoch: 50, Loss: 0.7666, Valid: 20.88%, Test: 5.63%
# Hits@1000
# Run: 01, Epoch: 50, Loss: 0.7666, Valid: 32.46%, Test: 23.07%
# Hits@10000
# Run: 01, Epoch: 50, Loss: 0.7666, Valid: 78.26%, Test: 79.55%
# ---
# Hits@20
# Run: 01, Epoch: 51, Loss: 0.7888, Valid: 15.39%, Test: 10.72%
# Hits@50
# Run: 01, Epoch: 51, Loss: 0.7888, Valid: 22.02%, Test: 16.04%
# Hits@100
# Run: 01, Epoch: 51, Loss: 0.7888, Valid: 27.63%, Test: 21.48%
# Hits@1000
# Run: 01, Epoch: 51, Loss: 0.7888, Valid: 46.26%, Test: 41.01%
# Hits@10000
# Run: 01, Epoch: 51, Loss: 0.7888, Valid: 78.14%, Test: 79.24%
# ---
# Hits@20
# Run: 01, Epoch: 52, Loss: 0.7764, Valid: 8.01%, Test: 0.73%
# Hits@50
# Run: 01, Epoch: 52, Loss: 0.7764, Valid: 10.62%, Test: 1.88%
# Hits@100
# Run: 01, Epoch: 52, Loss: 0.7764, Valid: 12.77%, Test: 3.01%
# Hits@1000
# Run: 01, Epoch: 52, Loss: 0.7764, Valid: 36.87%, Test: 28.83%
# Hits@10000
# Run: 01, Epoch: 52, Loss: 0.7764, Valid: 78.59%, Test: 78.24%
# ---
# Hits@20
# Run: 01, Epoch: 53, Loss: 0.7752, Valid: 13.60%, Test: 2.46%
# Hits@50
# Run: 01, Epoch: 53, Loss: 0.7752, Valid: 16.19%, Test: 4.33%
# Hits@100
# Run: 01, Epoch: 53, Loss: 0.7752, Valid: 18.13%, Test: 6.97%
# Hits@1000
# Run: 01, Epoch: 53, Loss: 0.7752, Valid: 35.12%, Test: 42.67%
# Hits@10000
# Run: 01, Epoch: 53, Loss: 0.7752, Valid: 79.28%, Test: 79.44%
# ---
# Hits@20
# Run: 01, Epoch: 54, Loss: 0.7644, Valid: 25.37%, Test: 8.45%
# Hits@50
# Run: 01, Epoch: 54, Loss: 0.7644, Valid: 29.82%, Test: 13.99%
# Hits@100
# Run: 01, Epoch: 54, Loss: 0.7644, Valid: 33.48%, Test: 18.02%
# Hits@1000
# Run: 01, Epoch: 54, Loss: 0.7644, Valid: 50.40%, Test: 41.65%
# Hits@10000
# Run: 01, Epoch: 54, Loss: 0.7644, Valid: 79.90%, Test: 79.14%
# ---
# Hits@20
# Run: 01, Epoch: 55, Loss: 0.7801, Valid: 13.93%, Test: 3.56%
# Hits@50
# Run: 01, Epoch: 55, Loss: 0.7801, Valid: 17.55%, Test: 5.19%
# Hits@100
# Run: 01, Epoch: 55, Loss: 0.7801, Valid: 20.12%, Test: 8.11%
# Hits@1000
# Run: 01, Epoch: 55, Loss: 0.7801, Valid: 44.99%, Test: 40.65%
# Hits@10000
# Run: 01, Epoch: 55, Loss: 0.7801, Valid: 79.43%, Test: 78.95%
# ---
# Hits@20
# Run: 01, Epoch: 56, Loss: 0.7480, Valid: 6.77%, Test: 1.94%
# Hits@50
# Run: 01, Epoch: 56, Loss: 0.7480, Valid: 8.32%, Test: 2.99%
# Hits@100
# Run: 01, Epoch: 56, Loss: 0.7480, Valid: 10.06%, Test: 4.93%
# Hits@1000
# Run: 01, Epoch: 56, Loss: 0.7480, Valid: 33.26%, Test: 26.36%
# Hits@10000
# Run: 01, Epoch: 56, Loss: 0.7480, Valid: 79.53%, Test: 79.43%
# ---
# Hits@20
# Run: 01, Epoch: 57, Loss: 0.7487, Valid: 3.66%, Test: 2.00%
# Hits@50
# Run: 01, Epoch: 57, Loss: 0.7487, Valid: 5.54%, Test: 3.26%
# Hits@100
# Run: 01, Epoch: 57, Loss: 0.7487, Valid: 6.70%, Test: 4.58%
# Hits@1000
# Run: 01, Epoch: 57, Loss: 0.7487, Valid: 24.08%, Test: 23.02%
# Hits@10000
# Run: 01, Epoch: 57, Loss: 0.7487, Valid: 79.51%, Test: 79.87%
# ---
# Hits@20
# Run: 01, Epoch: 58, Loss: 0.7424, Valid: 11.84%, Test: 3.04%
# Hits@50
# Run: 01, Epoch: 58, Loss: 0.7424, Valid: 16.56%, Test: 5.31%
# Hits@100
# Run: 01, Epoch: 58, Loss: 0.7424, Valid: 18.52%, Test: 7.63%
# Hits@1000
# Run: 01, Epoch: 58, Loss: 0.7424, Valid: 40.19%, Test: 36.94%
# Hits@10000
# Run: 01, Epoch: 58, Loss: 0.7424, Valid: 80.87%, Test: 80.85%
# ---
# Hits@20
# Run: 01, Epoch: 59, Loss: 0.7532, Valid: 7.59%, Test: 4.19%
# Hits@50
# Run: 01, Epoch: 59, Loss: 0.7532, Valid: 10.92%, Test: 6.67%
# Hits@100
# Run: 01, Epoch: 59, Loss: 0.7532, Valid: 14.13%, Test: 9.79%
# Hits@1000
# Run: 01, Epoch: 59, Loss: 0.7532, Valid: 41.64%, Test: 38.08%
# Hits@10000
# Run: 01, Epoch: 59, Loss: 0.7532, Valid: 80.15%, Test: 80.70%
# ---
# Hits@20
# Run: 01, Epoch: 60, Loss: 0.7587, Valid: 6.24%, Test: 1.98%
# Hits@50
# Run: 01, Epoch: 60, Loss: 0.7587, Valid: 7.72%, Test: 3.69%
# Hits@100
# Run: 01, Epoch: 60, Loss: 0.7587, Valid: 10.42%, Test: 6.02%
# Hits@1000
# Run: 01, Epoch: 60, Loss: 0.7587, Valid: 36.53%, Test: 34.91%
# Hits@10000
# Run: 01, Epoch: 60, Loss: 0.7587, Valid: 79.81%, Test: 79.82%
# ---
# Hits@20
# Run: 01, Epoch: 61, Loss: 0.7680, Valid: 15.98%, Test: 3.21%
# Hits@50
# Run: 01, Epoch: 61, Loss: 0.7680, Valid: 17.99%, Test: 4.97%
# Hits@100
# Run: 01, Epoch: 61, Loss: 0.7680, Valid: 20.66%, Test: 7.26%
# Hits@1000
# Run: 01, Epoch: 61, Loss: 0.7680, Valid: 39.45%, Test: 31.58%
# Hits@10000
# Run: 01, Epoch: 61, Loss: 0.7680, Valid: 80.38%, Test: 80.85%
# ---
# Hits@20
# Run: 01, Epoch: 62, Loss: 0.7415, Valid: 10.83%, Test: 3.04%
# Hits@50
# Run: 01, Epoch: 62, Loss: 0.7415, Valid: 15.13%, Test: 4.93%
# Hits@100
# Run: 01, Epoch: 62, Loss: 0.7415, Valid: 19.26%, Test: 8.61%
# Hits@1000
# Run: 01, Epoch: 62, Loss: 0.7415, Valid: 39.23%, Test: 34.78%
# Hits@10000
# Run: 01, Epoch: 62, Loss: 0.7415, Valid: 80.59%, Test: 80.75%
# ---
# Hits@20
# Run: 01, Epoch: 63, Loss: 0.7437, Valid: 6.02%, Test: 1.97%
# Hits@50
# Run: 01, Epoch: 63, Loss: 0.7437, Valid: 8.19%, Test: 3.17%
# Hits@100
# Run: 01, Epoch: 63, Loss: 0.7437, Valid: 9.69%, Test: 4.53%
# Hits@1000
# Run: 01, Epoch: 63, Loss: 0.7437, Valid: 34.58%, Test: 25.24%
# Hits@10000
# Run: 01, Epoch: 63, Loss: 0.7437, Valid: 80.07%, Test: 80.55%
# ---
# Hits@20
# Run: 01, Epoch: 64, Loss: 0.7320, Valid: 4.37%, Test: 1.92%
# Hits@50
# Run: 01, Epoch: 64, Loss: 0.7320, Valid: 6.52%, Test: 2.45%
# Hits@100
# Run: 01, Epoch: 64, Loss: 0.7320, Valid: 8.01%, Test: 3.58%
# Hits@1000
# Run: 01, Epoch: 64, Loss: 0.7320, Valid: 26.19%, Test: 18.68%
# Hits@10000
# Run: 01, Epoch: 64, Loss: 0.7320, Valid: 78.98%, Test: 79.54%
# ---
# Hits@20
# Run: 01, Epoch: 65, Loss: 0.7402, Valid: 7.02%, Test: 1.88%
# Hits@50
# Run: 01, Epoch: 65, Loss: 0.7402, Valid: 10.75%, Test: 4.26%
# Hits@100
# Run: 01, Epoch: 65, Loss: 0.7402, Valid: 15.58%, Test: 7.85%
# Hits@1000
# Run: 01, Epoch: 65, Loss: 0.7402, Valid: 41.13%, Test: 39.32%
# Hits@10000
# Run: 01, Epoch: 65, Loss: 0.7402, Valid: 79.63%, Test: 80.00%
# ---
# Hits@20
# Run: 01, Epoch: 66, Loss: 0.7481, Valid: 2.59%, Test: 1.73%
# Hits@50
# Run: 01, Epoch: 66, Loss: 0.7481, Valid: 4.33%, Test: 2.41%
# Hits@100
# Run: 01, Epoch: 66, Loss: 0.7481, Valid: 5.48%, Test: 3.58%
# Hits@1000
# Run: 01, Epoch: 66, Loss: 0.7481, Valid: 21.82%, Test: 19.39%
# Hits@10000
# Run: 01, Epoch: 66, Loss: 0.7481, Valid: 80.02%, Test: 80.71%
# ---
# Hits@20
# Run: 01, Epoch: 67, Loss: 0.7375, Valid: 6.47%, Test: 2.68%
# Hits@50
# Run: 01, Epoch: 67, Loss: 0.7375, Valid: 9.54%, Test: 4.62%
# Hits@100
# Run: 01, Epoch: 67, Loss: 0.7375, Valid: 12.31%, Test: 9.25%
# Hits@1000
# Run: 01, Epoch: 67, Loss: 0.7375, Valid: 41.33%, Test: 39.50%
# Hits@10000
# Run: 01, Epoch: 67, Loss: 0.7375, Valid: 80.40%, Test: 80.43%
# ---
# Hits@20
# Run: 01, Epoch: 68, Loss: 0.7483, Valid: 4.55%, Test: 1.66%
# Hits@50
# Run: 01, Epoch: 68, Loss: 0.7483, Valid: 7.08%, Test: 2.23%
# Hits@100
# Run: 01, Epoch: 68, Loss: 0.7483, Valid: 9.41%, Test: 2.86%
# Hits@1000
# Run: 01, Epoch: 68, Loss: 0.7483, Valid: 31.24%, Test: 28.41%
# Hits@10000
# Run: 01, Epoch: 68, Loss: 0.7483, Valid: 79.22%, Test: 79.66%
# ---
# Hits@20
# Run: 01, Epoch: 69, Loss: 0.7839, Valid: 13.68%, Test: 4.66%
# Hits@50
# Run: 01, Epoch: 69, Loss: 0.7839, Valid: 19.41%, Test: 6.97%
# Hits@100
# Run: 01, Epoch: 69, Loss: 0.7839, Valid: 24.63%, Test: 8.35%
# Hits@1000
# Run: 01, Epoch: 69, Loss: 0.7839, Valid: 36.17%, Test: 21.97%
# Hits@10000
# Run: 01, Epoch: 69, Loss: 0.7839, Valid: 77.16%, Test: 77.97%
# ---
# Hits@20
# Run: 01, Epoch: 70, Loss: 0.7976, Valid: 2.75%, Test: 1.65%
# Hits@50
# Run: 01, Epoch: 70, Loss: 0.7976, Valid: 4.62%, Test: 2.70%
# Hits@100
# Run: 01, Epoch: 70, Loss: 0.7976, Valid: 6.05%, Test: 3.74%
# Hits@1000
# Run: 01, Epoch: 70, Loss: 0.7976, Valid: 17.86%, Test: 13.96%
# Hits@10000
# Run: 01, Epoch: 70, Loss: 0.7976, Valid: 62.19%, Test: 65.87%
# ---
# Hits@20
# Run: 01, Epoch: 71, Loss: 0.7757, Valid: 16.53%, Test: 2.99%
# Hits@50
# Run: 01, Epoch: 71, Loss: 0.7757, Valid: 18.90%, Test: 4.21%
# Hits@100
# Run: 01, Epoch: 71, Loss: 0.7757, Valid: 20.10%, Test: 5.75%
# Hits@1000
# Run: 01, Epoch: 71, Loss: 0.7757, Valid: 31.69%, Test: 27.39%
# Hits@10000
# Run: 01, Epoch: 71, Loss: 0.7757, Valid: 76.00%, Test: 77.33%
# ---
# Hits@20
# Run: 01, Epoch: 72, Loss: 0.7897, Valid: 8.87%, Test: 1.55%
# Hits@50
# Run: 01, Epoch: 72, Loss: 0.7897, Valid: 15.91%, Test: 3.77%
# Hits@100
# Run: 01, Epoch: 72, Loss: 0.7897, Valid: 18.20%, Test: 7.30%
# Hits@1000
# Run: 01, Epoch: 72, Loss: 0.7897, Valid: 36.17%, Test: 39.33%
# Hits@10000
# Run: 01, Epoch: 72, Loss: 0.7897, Valid: 79.28%, Test: 79.28%
# ---
# Hits@20
# Run: 01, Epoch: 73, Loss: 0.7475, Valid: 1.85%, Test: 0.67%
# Hits@50
# Run: 01, Epoch: 73, Loss: 0.7475, Valid: 2.53%, Test: 1.51%
# Hits@100
# Run: 01, Epoch: 73, Loss: 0.7475, Valid: 4.37%, Test: 2.57%
# Hits@1000
# Run: 01, Epoch: 73, Loss: 0.7475, Valid: 19.48%, Test: 15.49%
# Hits@10000
# Run: 01, Epoch: 73, Loss: 0.7475, Valid: 77.59%, Test: 77.55%
# ---
# Hits@20
# Run: 01, Epoch: 74, Loss: 0.7532, Valid: 7.22%, Test: 4.70%
# Hits@50
# Run: 01, Epoch: 74, Loss: 0.7532, Valid: 19.72%, Test: 7.12%
# Hits@100
# Run: 01, Epoch: 74, Loss: 0.7532, Valid: 22.31%, Test: 10.31%
# Hits@1000
# Run: 01, Epoch: 74, Loss: 0.7532, Valid: 43.38%, Test: 33.07%
# Hits@10000
# Run: 01, Epoch: 74, Loss: 0.7532, Valid: 79.66%, Test: 80.14%
# ---
# Hits@20
# Run: 01, Epoch: 75, Loss: 0.7528, Valid: 7.55%, Test: 2.74%
# Hits@50
# Run: 01, Epoch: 75, Loss: 0.7528, Valid: 10.13%, Test: 3.73%
# Hits@100
# Run: 01, Epoch: 75, Loss: 0.7528, Valid: 11.43%, Test: 4.71%
# Hits@1000
# Run: 01, Epoch: 75, Loss: 0.7528, Valid: 23.99%, Test: 16.70%
# Hits@10000
# Run: 01, Epoch: 75, Loss: 0.7528, Valid: 78.44%, Test: 79.51%
# ---
# Hits@20
# Run: 01, Epoch: 76, Loss: 0.7472, Valid: 1.54%, Test: 0.90%
# Hits@50
# Run: 01, Epoch: 76, Loss: 0.7472, Valid: 1.84%, Test: 1.44%
# Hits@100
# Run: 01, Epoch: 76, Loss: 0.7472, Valid: 2.68%, Test: 2.07%
# Hits@1000
# Run: 01, Epoch: 76, Loss: 0.7472, Valid: 12.59%, Test: 12.65%
# Hits@10000
# Run: 01, Epoch: 76, Loss: 0.7472, Valid: 75.59%, Test: 75.30%
# ---
# Hits@20
# Run: 01, Epoch: 77, Loss: 0.7475, Valid: 8.12%, Test: 2.02%
# Hits@50
# Run: 01, Epoch: 77, Loss: 0.7475, Valid: 10.65%, Test: 3.00%
# Hits@100
# Run: 01, Epoch: 77, Loss: 0.7475, Valid: 13.88%, Test: 4.02%
# Hits@1000
# Run: 01, Epoch: 77, Loss: 0.7475, Valid: 36.83%, Test: 34.84%
# Hits@10000
# Run: 01, Epoch: 77, Loss: 0.7475, Valid: 80.32%, Test: 79.90%
# ---
# Hits@20
# Run: 01, Epoch: 78, Loss: 0.7389, Valid: 5.48%, Test: 2.02%
# Hits@50
# Run: 01, Epoch: 78, Loss: 0.7389, Valid: 9.21%, Test: 4.03%
# Hits@100
# Run: 01, Epoch: 78, Loss: 0.7389, Valid: 11.65%, Test: 5.44%
# Hits@1000
# Run: 01, Epoch: 78, Loss: 0.7389, Valid: 30.85%, Test: 23.71%
# Hits@10000
# Run: 01, Epoch: 78, Loss: 0.7389, Valid: 79.58%, Test: 80.84%
# ---
# Hits@20
# Run: 01, Epoch: 79, Loss: 0.7348, Valid: 2.29%, Test: 1.83%
# Hits@50
# Run: 01, Epoch: 79, Loss: 0.7348, Valid: 3.21%, Test: 3.02%
# Hits@100
# Run: 01, Epoch: 79, Loss: 0.7348, Valid: 4.65%, Test: 4.21%
# Hits@1000
# Run: 01, Epoch: 79, Loss: 0.7348, Valid: 17.61%, Test: 19.64%
# Hits@10000
# Run: 01, Epoch: 79, Loss: 0.7348, Valid: 77.93%, Test: 80.20%
# ---
# Hits@20
# Run: 01, Epoch: 80, Loss: 0.7345, Valid: 5.29%, Test: 1.87%
# Hits@50
# Run: 01, Epoch: 80, Loss: 0.7345, Valid: 6.10%, Test: 2.68%
# Hits@100
# Run: 01, Epoch: 80, Loss: 0.7345, Valid: 7.41%, Test: 3.80%
# Hits@1000
# Run: 01, Epoch: 80, Loss: 0.7345, Valid: 21.43%, Test: 15.72%
# Hits@10000
# Run: 01, Epoch: 80, Loss: 0.7345, Valid: 77.17%, Test: 77.10%
# ---
# Hits@20
# Run: 01, Epoch: 81, Loss: 0.7432, Valid: 6.91%, Test: 2.86%
# Hits@50
# Run: 01, Epoch: 81, Loss: 0.7432, Valid: 9.64%, Test: 4.20%
# Hits@100
# Run: 01, Epoch: 81, Loss: 0.7432, Valid: 12.29%, Test: 6.94%
# Hits@1000
# Run: 01, Epoch: 81, Loss: 0.7432, Valid: 37.23%, Test: 34.71%
# Hits@10000
# Run: 01, Epoch: 81, Loss: 0.7432, Valid: 79.12%, Test: 79.12%
# ---
# Hits@20
# Run: 01, Epoch: 82, Loss: 0.7299, Valid: 8.76%, Test: 2.10%
# Hits@50
# Run: 01, Epoch: 82, Loss: 0.7299, Valid: 11.39%, Test: 3.25%
# Hits@100
# Run: 01, Epoch: 82, Loss: 0.7299, Valid: 13.54%, Test: 5.09%
# Hits@1000
# Run: 01, Epoch: 82, Loss: 0.7299, Valid: 35.68%, Test: 36.59%
# Hits@10000
# Run: 01, Epoch: 82, Loss: 0.7299, Valid: 80.42%, Test: 80.85%
# ---
# Hits@20
# Run: 01, Epoch: 83, Loss: 0.7211, Valid: 8.00%, Test: 2.46%
# Hits@50
# Run: 01, Epoch: 83, Loss: 0.7211, Valid: 10.68%, Test: 3.79%
# Hits@100
# Run: 01, Epoch: 83, Loss: 0.7211, Valid: 13.71%, Test: 5.46%
# Hits@1000
# Run: 01, Epoch: 83, Loss: 0.7211, Valid: 32.04%, Test: 26.52%
# Hits@10000
# Run: 01, Epoch: 83, Loss: 0.7211, Valid: 80.35%, Test: 80.79%
# ---
# Hits@20
# Run: 01, Epoch: 84, Loss: 0.7282, Valid: 2.71%, Test: 2.81%
# Hits@50
# Run: 01, Epoch: 84, Loss: 0.7282, Valid: 3.81%, Test: 4.34%
# Hits@100
# Run: 01, Epoch: 84, Loss: 0.7282, Valid: 4.84%, Test: 6.36%
# Hits@1000
# Run: 01, Epoch: 84, Loss: 0.7282, Valid: 15.12%, Test: 20.62%
# Hits@10000
# Run: 01, Epoch: 84, Loss: 0.7282, Valid: 75.13%, Test: 77.24%
# ---
# Hits@20
# Run: 01, Epoch: 85, Loss: 0.7222, Valid: 2.64%, Test: 2.81%
# Hits@50
# Run: 01, Epoch: 85, Loss: 0.7222, Valid: 4.32%, Test: 3.66%
# Hits@100
# Run: 01, Epoch: 85, Loss: 0.7222, Valid: 5.64%, Test: 5.12%
# Hits@1000
# Run: 01, Epoch: 85, Loss: 0.7222, Valid: 22.34%, Test: 27.86%
# Hits@10000
# Run: 01, Epoch: 85, Loss: 0.7222, Valid: 80.13%, Test: 80.68%
# ---
# Hits@20
# Run: 01, Epoch: 86, Loss: 0.7395, Valid: 19.95%, Test: 10.28%
# Hits@50
# Run: 01, Epoch: 86, Loss: 0.7395, Valid: 24.90%, Test: 14.14%
# Hits@100
# Run: 01, Epoch: 86, Loss: 0.7395, Valid: 31.44%, Test: 19.36%
# Hits@1000
# Run: 01, Epoch: 86, Loss: 0.7395, Valid: 51.28%, Test: 40.81%
# Hits@10000
# Run: 01, Epoch: 86, Loss: 0.7395, Valid: 79.73%, Test: 79.49%
# ---
# Hits@20
# Run: 01, Epoch: 87, Loss: 0.7353, Valid: 2.57%, Test: 1.83%
# Hits@50
# Run: 01, Epoch: 87, Loss: 0.7353, Valid: 3.19%, Test: 2.90%
# Hits@100
# Run: 01, Epoch: 87, Loss: 0.7353, Valid: 3.92%, Test: 3.91%
# Hits@1000
# Run: 01, Epoch: 87, Loss: 0.7353, Valid: 15.71%, Test: 14.98%
# Hits@10000
# Run: 01, Epoch: 87, Loss: 0.7353, Valid: 68.53%, Test: 66.10%
# ---
# Hits@20
# Run: 01, Epoch: 88, Loss: 0.7490, Valid: 5.38%, Test: 2.91%
# Hits@50
# Run: 01, Epoch: 88, Loss: 0.7490, Valid: 11.19%, Test: 6.31%
# Hits@100
# Run: 01, Epoch: 88, Loss: 0.7490, Valid: 16.33%, Test: 11.17%
# Hits@1000
# Run: 01, Epoch: 88, Loss: 0.7490, Valid: 49.54%, Test: 44.82%
# Hits@10000
# Run: 01, Epoch: 88, Loss: 0.7490, Valid: 81.48%, Test: 81.40%
# ---
# Hits@20
# Run: 01, Epoch: 89, Loss: 0.7333, Valid: 6.69%, Test: 2.14%
# Hits@50
# Run: 01, Epoch: 89, Loss: 0.7333, Valid: 10.52%, Test: 3.85%
# Hits@100
# Run: 01, Epoch: 89, Loss: 0.7333, Valid: 13.66%, Test: 6.66%
# Hits@1000
# Run: 01, Epoch: 89, Loss: 0.7333, Valid: 41.74%, Test: 41.57%
# Hits@10000
# Run: 01, Epoch: 89, Loss: 0.7333, Valid: 79.41%, Test: 80.01%
# ---
# Hits@20
# Run: 01, Epoch: 90, Loss: 0.7418, Valid: 2.15%, Test: 1.69%
# Hits@50
# Run: 01, Epoch: 90, Loss: 0.7418, Valid: 2.69%, Test: 2.48%
# Hits@100
# Run: 01, Epoch: 90, Loss: 0.7418, Valid: 3.36%, Test: 4.02%
# Hits@1000
# Run: 01, Epoch: 90, Loss: 0.7418, Valid: 22.30%, Test: 22.15%
# Hits@10000
# Run: 01, Epoch: 90, Loss: 0.7418, Valid: 76.72%, Test: 76.70%
# ---
# Hits@20
# Run: 01, Epoch: 91, Loss: 0.7299, Valid: 1.81%, Test: 1.87%
# Hits@50
# Run: 01, Epoch: 91, Loss: 0.7299, Valid: 3.21%, Test: 2.66%
# Hits@100
# Run: 01, Epoch: 91, Loss: 0.7299, Valid: 4.78%, Test: 4.19%
# Hits@1000
# Run: 01, Epoch: 91, Loss: 0.7299, Valid: 18.62%, Test: 21.41%
# Hits@10000
# Run: 01, Epoch: 91, Loss: 0.7299, Valid: 78.52%, Test: 78.48%
# ---
# Hits@20
# Run: 01, Epoch: 92, Loss: 0.7374, Valid: 3.01%, Test: 2.12%
# Hits@50
# Run: 01, Epoch: 92, Loss: 0.7374, Valid: 5.65%, Test: 3.33%
# Hits@100
# Run: 01, Epoch: 92, Loss: 0.7374, Valid: 7.78%, Test: 4.70%
# Hits@1000
# Run: 01, Epoch: 92, Loss: 0.7374, Valid: 29.75%, Test: 30.02%
# Hits@10000
# Run: 01, Epoch: 92, Loss: 0.7374, Valid: 79.08%, Test: 78.65%
# ---
# Hits@20
# Run: 01, Epoch: 93, Loss: 0.7375, Valid: 2.48%, Test: 2.32%
# Hits@50
# Run: 01, Epoch: 93, Loss: 0.7375, Valid: 3.67%, Test: 3.63%
# Hits@100
# Run: 01, Epoch: 93, Loss: 0.7375, Valid: 4.97%, Test: 4.95%
# Hits@1000
# Run: 01, Epoch: 93, Loss: 0.7375, Valid: 20.17%, Test: 23.71%
# Hits@10000
# Run: 01, Epoch: 93, Loss: 0.7375, Valid: 79.33%, Test: 79.24%
# ---
# Hits@20
# Run: 01, Epoch: 94, Loss: 0.7299, Valid: 8.03%, Test: 2.15%
# Hits@50
# Run: 01, Epoch: 94, Loss: 0.7299, Valid: 17.23%, Test: 8.72%
# Hits@100
# Run: 01, Epoch: 94, Loss: 0.7299, Valid: 21.45%, Test: 20.61%
# Hits@1000
# Run: 01, Epoch: 94, Loss: 0.7299, Valid: 52.75%, Test: 54.54%
# Hits@10000
# Run: 01, Epoch: 94, Loss: 0.7299, Valid: 79.70%, Test: 79.48%
# ---
# Hits@20
# Run: 01, Epoch: 95, Loss: 0.7393, Valid: 2.60%, Test: 2.54%
# Hits@50
# Run: 01, Epoch: 95, Loss: 0.7393, Valid: 3.70%, Test: 4.33%
# Hits@100
# Run: 01, Epoch: 95, Loss: 0.7393, Valid: 5.19%, Test: 6.19%
# Hits@1000
# Run: 01, Epoch: 95, Loss: 0.7393, Valid: 17.50%, Test: 22.90%
# Hits@10000
# Run: 01, Epoch: 95, Loss: 0.7393, Valid: 79.87%, Test: 80.82%
# ---
# Hits@20
# Run: 01, Epoch: 96, Loss: 0.7213, Valid: 3.75%, Test: 1.49%
# Hits@50
# Run: 01, Epoch: 96, Loss: 0.7213, Valid: 5.02%, Test: 2.39%
# Hits@100
# Run: 01, Epoch: 96, Loss: 0.7213, Valid: 6.00%, Test: 3.63%
# Hits@1000
# Run: 01, Epoch: 96, Loss: 0.7213, Valid: 22.15%, Test: 17.74%
# Hits@10000
# Run: 01, Epoch: 96, Loss: 0.7213, Valid: 79.01%, Test: 80.03%
# ---
# Hits@20
# Run: 01, Epoch: 97, Loss: 0.7245, Valid: 11.42%, Test: 2.16%
# Hits@50
# Run: 01, Epoch: 97, Loss: 0.7245, Valid: 13.89%, Test: 3.66%
# Hits@100
# Run: 01, Epoch: 97, Loss: 0.7245, Valid: 17.47%, Test: 4.80%
# Hits@1000
# Run: 01, Epoch: 97, Loss: 0.7245, Valid: 31.31%, Test: 18.36%
# Hits@10000
# Run: 01, Epoch: 97, Loss: 0.7245, Valid: 79.39%, Test: 79.86%
# ---
# Hits@20
# Run: 01, Epoch: 98, Loss: 0.7217, Valid: 0.91%, Test: 1.59%
# Hits@50
# Run: 01, Epoch: 98, Loss: 0.7217, Valid: 1.43%, Test: 2.90%
# Hits@100
# Run: 01, Epoch: 98, Loss: 0.7217, Valid: 2.32%, Test: 4.07%
# Hits@1000
# Run: 01, Epoch: 98, Loss: 0.7217, Valid: 12.42%, Test: 17.96%
# Hits@10000
# Run: 01, Epoch: 98, Loss: 0.7217, Valid: 76.31%, Test: 77.43%
# ---
# Hits@20
# Run: 01, Epoch: 99, Loss: 0.7215, Valid: 9.37%, Test: 2.10%
# Hits@50
# Run: 01, Epoch: 99, Loss: 0.7215, Valid: 11.62%, Test: 3.02%
# Hits@100
# Run: 01, Epoch: 99, Loss: 0.7215, Valid: 13.42%, Test: 4.61%
# Hits@1000
# Run: 01, Epoch: 99, Loss: 0.7215, Valid: 32.54%, Test: 24.43%
# Hits@10000
# Run: 01, Epoch: 99, Loss: 0.7215, Valid: 81.28%, Test: 82.03%
# ---
# Hits@20
# Run: 01, Epoch: 100, Loss: 0.7247, Valid: 5.50%, Test: 1.88%
# Hits@50
# Run: 01, Epoch: 100, Loss: 0.7247, Valid: 8.49%, Test: 3.40%
# Hits@100
# Run: 01, Epoch: 100, Loss: 0.7247, Valid: 11.99%, Test: 4.79%
# Hits@1000
# Run: 01, Epoch: 100, Loss: 0.7247, Valid: 28.04%, Test: 20.21%
# Hits@10000
# Run: 01, Epoch: 100, Loss: 0.7247, Valid: 77.81%, Test: 79.41%
# ---
# Hits@20
# Run: 01, Epoch: 101, Loss: 0.7393, Valid: 7.94%, Test: 1.28%
# Hits@50
# Run: 01, Epoch: 101, Loss: 0.7393, Valid: 9.46%, Test: 2.59%
# Hits@100
# Run: 01, Epoch: 101, Loss: 0.7393, Valid: 12.86%, Test: 4.30%
# Hits@1000
# Run: 01, Epoch: 101, Loss: 0.7393, Valid: 35.76%, Test: 27.34%
# Hits@10000
# Run: 01, Epoch: 101, Loss: 0.7393, Valid: 78.59%, Test: 79.44%
# ---
# Hits@20
# Run: 01, Epoch: 102, Loss: 0.7507, Valid: 1.21%, Test: 1.60%
# Hits@50
# Run: 01, Epoch: 102, Loss: 0.7507, Valid: 3.00%, Test: 3.32%
# Hits@100
# Run: 01, Epoch: 102, Loss: 0.7507, Valid: 5.03%, Test: 5.84%
# Hits@1000
# Run: 01, Epoch: 102, Loss: 0.7507, Valid: 31.59%, Test: 36.32%
# Hits@10000
# Run: 01, Epoch: 102, Loss: 0.7507, Valid: 78.68%, Test: 78.83%
# ---
# Hits@20
# Run: 01, Epoch: 103, Loss: 0.7287, Valid: 2.20%, Test: 1.86%
# Hits@50
# Run: 01, Epoch: 103, Loss: 0.7287, Valid: 3.15%, Test: 3.16%
# Hits@100
# Run: 01, Epoch: 103, Loss: 0.7287, Valid: 4.14%, Test: 4.59%
# Hits@1000
# Run: 01, Epoch: 103, Loss: 0.7287, Valid: 21.45%, Test: 22.05%
# Hits@10000
# Run: 01, Epoch: 103, Loss: 0.7287, Valid: 79.43%, Test: 79.97%
# ---
# Hits@20
# Run: 01, Epoch: 104, Loss: 0.7213, Valid: 2.02%, Test: 2.04%
# Hits@50
# Run: 01, Epoch: 104, Loss: 0.7213, Valid: 2.94%, Test: 3.50%
# Hits@100
# Run: 01, Epoch: 104, Loss: 0.7213, Valid: 3.78%, Test: 5.10%
# Hits@1000
# Run: 01, Epoch: 104, Loss: 0.7213, Valid: 17.44%, Test: 20.99%
# Hits@10000
# Run: 01, Epoch: 104, Loss: 0.7213, Valid: 78.14%, Test: 79.17%
# ---
# Hits@20
# Run: 01, Epoch: 105, Loss: 0.7125, Valid: 3.36%, Test: 1.83%
# Hits@50
# Run: 01, Epoch: 105, Loss: 0.7125, Valid: 4.13%, Test: 2.43%
# Hits@100
# Run: 01, Epoch: 105, Loss: 0.7125, Valid: 5.22%, Test: 3.33%
# Hits@1000
# Run: 01, Epoch: 105, Loss: 0.7125, Valid: 17.59%, Test: 15.41%
# Hits@10000
# Run: 01, Epoch: 105, Loss: 0.7125, Valid: 78.78%, Test: 79.87%
# ---
# Hits@20
# Run: 01, Epoch: 106, Loss: 0.7265, Valid: 5.49%, Test: 2.24%
# Hits@50
# Run: 01, Epoch: 106, Loss: 0.7265, Valid: 7.88%, Test: 4.16%
# Hits@100
# Run: 01, Epoch: 106, Loss: 0.7265, Valid: 10.46%, Test: 5.77%
# Hits@1000
# Run: 01, Epoch: 106, Loss: 0.7265, Valid: 34.80%, Test: 27.93%
# Hits@10000
# Run: 01, Epoch: 106, Loss: 0.7265, Valid: 78.52%, Test: 79.95%
# ---
# Hits@20
# Run: 01, Epoch: 107, Loss: 0.7235, Valid: 6.41%, Test: 2.63%
# Hits@50
# Run: 01, Epoch: 107, Loss: 0.7235, Valid: 8.65%, Test: 3.97%
# Hits@100
# Run: 01, Epoch: 107, Loss: 0.7235, Valid: 10.17%, Test: 6.06%
# Hits@1000
# Run: 01, Epoch: 107, Loss: 0.7235, Valid: 33.02%, Test: 28.03%
# Hits@10000
# Run: 01, Epoch: 107, Loss: 0.7235, Valid: 79.21%, Test: 79.83%
# ---
# Hits@20
# Run: 01, Epoch: 108, Loss: 0.7242, Valid: 4.87%, Test: 2.80%
# Hits@50
# Run: 01, Epoch: 108, Loss: 0.7242, Valid: 7.08%, Test: 4.21%
# Hits@100
# Run: 01, Epoch: 108, Loss: 0.7242, Valid: 8.61%, Test: 6.02%
# Hits@1000
# Run: 01, Epoch: 108, Loss: 0.7242, Valid: 25.79%, Test: 21.54%
# Hits@10000
# Run: 01, Epoch: 108, Loss: 0.7242, Valid: 78.17%, Test: 77.70%
# ---
# Hits@20
# Run: 01, Epoch: 109, Loss: 0.7116, Valid: 6.03%, Test: 2.91%
# Hits@50
# Run: 01, Epoch: 109, Loss: 0.7116, Valid: 9.11%, Test: 4.15%
# Hits@100
# Run: 01, Epoch: 109, Loss: 0.7116, Valid: 11.55%, Test: 5.13%
# Hits@1000
# Run: 01, Epoch: 109, Loss: 0.7116, Valid: 29.00%, Test: 19.33%
# Hits@10000
# Run: 01, Epoch: 109, Loss: 0.7116, Valid: 76.75%, Test: 73.84%
# ---
# Hits@20
# Run: 01, Epoch: 110, Loss: 0.7325, Valid: 1.05%, Test: 0.86%
# Hits@50
# Run: 01, Epoch: 110, Loss: 0.7325, Valid: 1.48%, Test: 1.48%
# Hits@100
# Run: 01, Epoch: 110, Loss: 0.7325, Valid: 2.04%, Test: 2.44%
# Hits@1000
# Run: 01, Epoch: 110, Loss: 0.7325, Valid: 9.74%, Test: 10.75%
# Hits@10000
# Run: 01, Epoch: 110, Loss: 0.7325, Valid: 62.02%, Test: 58.29%
# ---
# Hits@20
# Run: 01, Epoch: 111, Loss: 0.7374, Valid: 4.24%, Test: 2.43%
# Hits@50
# Run: 01, Epoch: 111, Loss: 0.7374, Valid: 5.84%, Test: 3.38%
# Hits@100
# Run: 01, Epoch: 111, Loss: 0.7374, Valid: 7.45%, Test: 4.83%
# Hits@1000
# Run: 01, Epoch: 111, Loss: 0.7374, Valid: 24.94%, Test: 19.40%
# Hits@10000
# Run: 01, Epoch: 111, Loss: 0.7374, Valid: 77.83%, Test: 79.95%
# ---
# Hits@20
# Run: 01, Epoch: 112, Loss: 0.7250, Valid: 7.96%, Test: 3.34%
# Hits@50
# Run: 01, Epoch: 112, Loss: 0.7250, Valid: 12.41%, Test: 8.88%
# Hits@100
# Run: 01, Epoch: 112, Loss: 0.7250, Valid: 18.30%, Test: 12.17%
# Hits@1000
# Run: 01, Epoch: 112, Loss: 0.7250, Valid: 44.53%, Test: 41.85%
# Hits@10000
# Run: 01, Epoch: 112, Loss: 0.7250, Valid: 80.50%, Test: 79.63%
# ---
# Hits@20
# Run: 01, Epoch: 113, Loss: 0.7429, Valid: 3.38%, Test: 2.67%
# Hits@50
# Run: 01, Epoch: 113, Loss: 0.7429, Valid: 6.60%, Test: 5.66%
# Hits@100
# Run: 01, Epoch: 113, Loss: 0.7429, Valid: 9.77%, Test: 8.58%
# Hits@1000
# Run: 01, Epoch: 113, Loss: 0.7429, Valid: 40.01%, Test: 39.64%
# Hits@10000
# Run: 01, Epoch: 113, Loss: 0.7429, Valid: 80.76%, Test: 80.70%
# ---
# Hits@20
# Run: 01, Epoch: 114, Loss: 0.7157, Valid: 1.85%, Test: 2.21%
# Hits@50
# Run: 01, Epoch: 114, Loss: 0.7157, Valid: 2.80%, Test: 4.13%
# Hits@100
# Run: 01, Epoch: 114, Loss: 0.7157, Valid: 4.01%, Test: 6.13%
# Hits@1000
# Run: 01, Epoch: 114, Loss: 0.7157, Valid: 23.47%, Test: 25.91%
# Hits@10000
# Run: 01, Epoch: 114, Loss: 0.7157, Valid: 79.64%, Test: 80.28%
# ---
# Hits@20
# Run: 01, Epoch: 115, Loss: 0.7304, Valid: 5.36%, Test: 2.36%
# Hits@50
# Run: 01, Epoch: 115, Loss: 0.7304, Valid: 6.58%, Test: 3.05%
# Hits@100
# Run: 01, Epoch: 115, Loss: 0.7304, Valid: 7.75%, Test: 4.12%
# Hits@1000
# Run: 01, Epoch: 115, Loss: 0.7304, Valid: 19.74%, Test: 15.83%
# Hits@10000
# Run: 01, Epoch: 115, Loss: 0.7304, Valid: 77.54%, Test: 78.01%
# ---
# Hits@20
# Run: 01, Epoch: 116, Loss: 0.7200, Valid: 3.63%, Test: 1.89%
# Hits@50
# Run: 01, Epoch: 116, Loss: 0.7200, Valid: 5.75%, Test: 3.07%
# Hits@100
# Run: 01, Epoch: 116, Loss: 0.7200, Valid: 7.57%, Test: 5.09%
# Hits@1000
# Run: 01, Epoch: 116, Loss: 0.7200, Valid: 29.64%, Test: 27.04%
# Hits@10000
# Run: 01, Epoch: 116, Loss: 0.7200, Valid: 81.76%, Test: 81.79%
# ---
# Hits@20
# Run: 01, Epoch: 117, Loss: 0.7108, Valid: 2.12%, Test: 1.82%
# Hits@50
# Run: 01, Epoch: 117, Loss: 0.7108, Valid: 2.95%, Test: 2.94%
# Hits@100
# Run: 01, Epoch: 117, Loss: 0.7108, Valid: 3.89%, Test: 4.21%
# Hits@1000
# Run: 01, Epoch: 117, Loss: 0.7108, Valid: 12.89%, Test: 15.79%
# Hits@10000
# Run: 01, Epoch: 117, Loss: 0.7108, Valid: 73.62%, Test: 72.84%
# ---
# Hits@20
# Run: 01, Epoch: 118, Loss: 0.7114, Valid: 7.59%, Test: 3.74%
# Hits@50
# Run: 01, Epoch: 118, Loss: 0.7114, Valid: 13.11%, Test: 7.40%
# Hits@100
# Run: 01, Epoch: 118, Loss: 0.7114, Valid: 17.60%, Test: 11.40%
# Hits@1000
# Run: 01, Epoch: 118, Loss: 0.7114, Valid: 44.32%, Test: 39.11%
# Hits@10000
# Run: 01, Epoch: 118, Loss: 0.7114, Valid: 79.49%, Test: 79.19%
# ---
# Hits@20
# Run: 01, Epoch: 119, Loss: 0.7184, Valid: 8.06%, Test: 2.44%
# Hits@50
# Run: 01, Epoch: 119, Loss: 0.7184, Valid: 11.52%, Test: 3.21%
# Hits@100
# Run: 01, Epoch: 119, Loss: 0.7184, Valid: 13.23%, Test: 4.52%
# Hits@1000
# Run: 01, Epoch: 119, Loss: 0.7184, Valid: 31.78%, Test: 26.38%
# Hits@10000
# Run: 01, Epoch: 119, Loss: 0.7184, Valid: 81.27%, Test: 81.47%
# ---
# Hits@20
# Run: 01, Epoch: 120, Loss: 0.7149, Valid: 1.13%, Test: 1.99%
# Hits@50
# Run: 01, Epoch: 120, Loss: 0.7149, Valid: 2.24%, Test: 3.11%
# Hits@100
# Run: 01, Epoch: 120, Loss: 0.7149, Valid: 3.82%, Test: 4.72%
# Hits@1000
# Run: 01, Epoch: 120, Loss: 0.7149, Valid: 23.81%, Test: 25.37%
# Hits@10000
# Run: 01, Epoch: 120, Loss: 0.7149, Valid: 79.43%, Test: 79.12%
# ---
# Hits@20
# Run: 01, Epoch: 121, Loss: 0.7410, Valid: 5.86%, Test: 2.29%
# Hits@50
# Run: 01, Epoch: 121, Loss: 0.7410, Valid: 7.17%, Test: 3.26%
# Hits@100
# Run: 01, Epoch: 121, Loss: 0.7410, Valid: 8.84%, Test: 4.57%
# Hits@1000
# Run: 01, Epoch: 121, Loss: 0.7410, Valid: 24.73%, Test: 25.59%
# Hits@10000
# Run: 01, Epoch: 121, Loss: 0.7410, Valid: 78.94%, Test: 80.53%
# ---
# Hits@20
# Run: 01, Epoch: 122, Loss: 0.7278, Valid: 3.99%, Test: 2.55%
# Hits@50
# Run: 01, Epoch: 122, Loss: 0.7278, Valid: 5.88%, Test: 3.67%
# Hits@100
# Run: 01, Epoch: 122, Loss: 0.7278, Valid: 7.38%, Test: 4.86%
# Hits@1000
# Run: 01, Epoch: 122, Loss: 0.7278, Valid: 26.38%, Test: 21.11%
# Hits@10000
# Run: 01, Epoch: 122, Loss: 0.7278, Valid: 78.07%, Test: 79.78%
# ---
# Hits@20
# Run: 01, Epoch: 123, Loss: 0.7090, Valid: 4.58%, Test: 5.24%
# Hits@50
# Run: 01, Epoch: 123, Loss: 0.7090, Valid: 11.75%, Test: 9.16%
# Hits@100
# Run: 01, Epoch: 123, Loss: 0.7090, Valid: 18.67%, Test: 13.40%
# Hits@1000
# Run: 01, Epoch: 123, Loss: 0.7090, Valid: 47.32%, Test: 37.50%
# Hits@10000
# Run: 01, Epoch: 123, Loss: 0.7090, Valid: 79.23%, Test: 79.02%
# ---
# Hits@20
# Run: 01, Epoch: 124, Loss: 0.7087, Valid: 2.39%, Test: 1.80%
# Hits@50
# Run: 01, Epoch: 124, Loss: 0.7087, Valid: 3.43%, Test: 3.08%
# Hits@100
# Run: 01, Epoch: 124, Loss: 0.7087, Valid: 4.96%, Test: 4.15%
# Hits@1000
# Run: 01, Epoch: 124, Loss: 0.7087, Valid: 22.27%, Test: 20.79%
# Hits@10000
# Run: 01, Epoch: 124, Loss: 0.7087, Valid: 78.74%, Test: 80.02%
# ---
# Hits@20
# Run: 01, Epoch: 125, Loss: 0.7210, Valid: 2.53%, Test: 2.19%
# Hits@50
# Run: 01, Epoch: 125, Loss: 0.7210, Valid: 4.14%, Test: 3.40%
# Hits@100
# Run: 01, Epoch: 125, Loss: 0.7210, Valid: 5.93%, Test: 4.59%
# Hits@1000
# Run: 01, Epoch: 125, Loss: 0.7210, Valid: 22.67%, Test: 19.19%
# Hits@10000
# Run: 01, Epoch: 125, Loss: 0.7210, Valid: 78.02%, Test: 79.66%
# ---
# Hits@20
# Run: 01, Epoch: 126, Loss: 0.7120, Valid: 0.45%, Test: 1.22%
# Hits@50
# Run: 01, Epoch: 126, Loss: 0.7120, Valid: 1.35%, Test: 2.53%
# Hits@100
# Run: 01, Epoch: 126, Loss: 0.7120, Valid: 2.75%, Test: 4.06%
# Hits@1000
# Run: 01, Epoch: 126, Loss: 0.7120, Valid: 15.93%, Test: 15.09%
# Hits@10000
# Run: 01, Epoch: 126, Loss: 0.7120, Valid: 75.10%, Test: 78.52%
# ---
# Hits@20
# Run: 01, Epoch: 127, Loss: 0.7240, Valid: 0.88%, Test: 1.31%
# Hits@50
# Run: 01, Epoch: 127, Loss: 0.7240, Valid: 1.92%, Test: 2.18%
# Hits@100
# Run: 01, Epoch: 127, Loss: 0.7240, Valid: 2.94%, Test: 3.22%
# Hits@1000
# Run: 01, Epoch: 127, Loss: 0.7240, Valid: 11.84%, Test: 12.74%
# Hits@10000
# Run: 01, Epoch: 127, Loss: 0.7240, Valid: 74.19%, Test: 77.05%
# ---
# Hits@20
# Run: 01, Epoch: 128, Loss: 0.7106, Valid: 0.72%, Test: 1.24%
# Hits@50
# Run: 01, Epoch: 128, Loss: 0.7106, Valid: 1.34%, Test: 2.17%
# Hits@100
# Run: 01, Epoch: 128, Loss: 0.7106, Valid: 3.11%, Test: 3.63%
# Hits@1000
# Run: 01, Epoch: 128, Loss: 0.7106, Valid: 14.83%, Test: 15.02%
# Hits@10000
# Run: 01, Epoch: 128, Loss: 0.7106, Valid: 74.32%, Test: 67.72%
# ---
# Hits@20
# Run: 01, Epoch: 129, Loss: 0.7169, Valid: 1.62%, Test: 1.96%
# Hits@50
# Run: 01, Epoch: 129, Loss: 0.7169, Valid: 2.71%, Test: 3.14%
# Hits@100
# Run: 01, Epoch: 129, Loss: 0.7169, Valid: 3.74%, Test: 4.32%
# Hits@1000
# Run: 01, Epoch: 129, Loss: 0.7169, Valid: 17.75%, Test: 14.98%
# Hits@10000
# Run: 01, Epoch: 129, Loss: 0.7169, Valid: 75.23%, Test: 75.64%
# ---
# Hits@20
# Run: 01, Epoch: 130, Loss: 0.7202, Valid: 14.39%, Test: 3.80%
# Hits@50
# Run: 01, Epoch: 130, Loss: 0.7202, Valid: 16.60%, Test: 5.74%
# Hits@100
# Run: 01, Epoch: 130, Loss: 0.7202, Valid: 18.68%, Test: 8.59%
# Hits@1000
# Run: 01, Epoch: 130, Loss: 0.7202, Valid: 41.64%, Test: 32.25%
# Hits@10000
# Run: 01, Epoch: 130, Loss: 0.7202, Valid: 79.01%, Test: 80.04%
# ---
# Hits@20
# Run: 01, Epoch: 131, Loss: 0.7053, Valid: 2.68%, Test: 2.42%
# Hits@50
# Run: 01, Epoch: 131, Loss: 0.7053, Valid: 3.57%, Test: 3.44%
# Hits@100
# Run: 01, Epoch: 131, Loss: 0.7053, Valid: 4.56%, Test: 4.95%
# Hits@1000
# Run: 01, Epoch: 131, Loss: 0.7053, Valid: 21.35%, Test: 17.39%
# Hits@10000
# Run: 01, Epoch: 131, Loss: 0.7053, Valid: 74.78%, Test: 74.33%
# ---
# Hits@20
# Run: 01, Epoch: 132, Loss: 0.7062, Valid: 2.60%, Test: 2.04%
# Hits@50
# Run: 01, Epoch: 132, Loss: 0.7062, Valid: 3.38%, Test: 3.05%
# Hits@100
# Run: 01, Epoch: 132, Loss: 0.7062, Valid: 4.43%, Test: 4.58%
# Hits@1000
# Run: 01, Epoch: 132, Loss: 0.7062, Valid: 27.97%, Test: 22.75%
# Hits@10000
# Run: 01, Epoch: 132, Loss: 0.7062, Valid: 77.17%, Test: 77.18%
# ---
# Hits@20
# Run: 01, Epoch: 133, Loss: 0.7183, Valid: 4.41%, Test: 2.79%
# Hits@50
# Run: 01, Epoch: 133, Loss: 0.7183, Valid: 5.60%, Test: 4.81%
# Hits@100
# Run: 01, Epoch: 133, Loss: 0.7183, Valid: 6.88%, Test: 6.73%
# Hits@1000
# Run: 01, Epoch: 133, Loss: 0.7183, Valid: 22.04%, Test: 22.77%
# Hits@10000
# Run: 01, Epoch: 133, Loss: 0.7183, Valid: 78.01%, Test: 79.08%
# ---
# Hits@20
# Run: 01, Epoch: 134, Loss: 0.7275, Valid: 5.98%, Test: 2.52%
# Hits@50
# Run: 01, Epoch: 134, Loss: 0.7275, Valid: 7.94%, Test: 4.17%
# Hits@100
# Run: 01, Epoch: 134, Loss: 0.7275, Valid: 9.51%, Test: 5.64%
# Hits@1000
# Run: 01, Epoch: 134, Loss: 0.7275, Valid: 28.30%, Test: 25.51%
# Hits@10000
# Run: 01, Epoch: 134, Loss: 0.7275, Valid: 78.38%, Test: 80.71%
# ---
# Hits@20
# Run: 01, Epoch: 135, Loss: 0.7239, Valid: 9.70%, Test: 5.39%
# ...
# Hits@1000
# Run: 01, Epoch: 156, Loss: 0.7030, Valid: 19.04%, Test: 14.12%
# Hits@10000
# Run: 01, Epoch: 156, Loss: 0.7030, Valid: 76.28%, Test: 79.92%
# ---
# Hits@20
# Run: 01, Epoch: 157, Loss: 0.7200, Valid: 6.63%, Test: 0.96%
# Hits@50
# Run: 01, Epoch: 157, Loss: 0.7200, Valid: 8.11%, Test: 2.28%
# Hits@100
# Run: 01, Epoch: 157, Loss: 0.7200, Valid: 10.11%, Test: 3.43%
# Hits@1000
# Run: 01, Epoch: 157, Loss: 0.7200, Valid: 27.59%, Test: 15.83%
# Hits@10000
# Run: 01, Epoch: 157, Loss: 0.7200, Valid: 77.28%, Test: 80.88%
# ---
# Hits@20
# Run: 01, Epoch: 158, Loss: 0.7038, Valid: 5.30%, Test: 2.79%
# Hits@50
# Run: 01, Epoch: 158, Loss: 0.7038, Valid: 6.82%, Test: 4.12%
# Hits@100
# Run: 01, Epoch: 158, Loss: 0.7038, Valid: 8.38%, Test: 6.04%
# Hits@1000
# Run: 01, Epoch: 158, Loss: 0.7038, Valid: 38.28%, Test: 30.90%
# Hits@10000
# Run: 01, Epoch: 158, Loss: 0.7038, Valid: 79.04%, Test: 80.32%
# ---
# Hits@20
# Run: 01, Epoch: 159, Loss: 0.7037, Valid: 3.22%, Test: 2.98%
# Hits@50
# Run: 01, Epoch: 159, Loss: 0.7037, Valid: 4.52%, Test: 4.21%
# Hits@100
# Run: 01, Epoch: 159, Loss: 0.7037, Valid: 6.25%, Test: 5.59%
# Hits@1000
# Run: 01, Epoch: 159, Loss: 0.7037, Valid: 34.96%, Test: 29.13%
# Hits@10000
# Run: 01, Epoch: 159, Loss: 0.7037, Valid: 79.41%, Test: 81.06%
# ---
# Hits@20
# Run: 01, Epoch: 160, Loss: 0.6932, Valid: 4.98%, Test: 2.69%
# Hits@50
# Run: 01, Epoch: 160, Loss: 0.6932, Valid: 7.43%, Test: 4.55%
# Hits@100
# Run: 01, Epoch: 160, Loss: 0.6932, Valid: 11.92%, Test: 7.42%
# Hits@1000
# Run: 01, Epoch: 160, Loss: 0.6932, Valid: 39.79%, Test: 30.68%
# Hits@10000
# Run: 01, Epoch: 160, Loss: 0.6932, Valid: 79.78%, Test: 79.63%
# ---
# Hits@20
# Run: 01, Epoch: 161, Loss: 0.7100, Valid: 4.91%, Test: 3.33%
# Hits@50
# Run: 01, Epoch: 161, Loss: 0.7100, Valid: 18.23%, Test: 14.76%
# Hits@100
# Run: 01, Epoch: 161, Loss: 0.7100, Valid: 28.30%, Test: 20.12%
# Hits@1000
# Run: 01, Epoch: 161, Loss: 0.7100, Valid: 51.52%, Test: 36.72%
# Hits@10000
# Run: 01, Epoch: 161, Loss: 0.7100, Valid: 76.83%, Test: 79.39%
# ---
# Hits@20
# Run: 01, Epoch: 162, Loss: 0.7382, Valid: 5.78%, Test: 3.27%
# Hits@50
# Run: 01, Epoch: 162, Loss: 0.7382, Valid: 14.15%, Test: 8.87%
# Hits@100
# Run: 01, Epoch: 162, Loss: 0.7382, Valid: 18.96%, Test: 17.00%
# Hits@1000
# Run: 01, Epoch: 162, Loss: 0.7382, Valid: 50.31%, Test: 36.75%
# Hits@10000
# Run: 01, Epoch: 162, Loss: 0.7382, Valid: 79.65%, Test: 80.21%
# ---
# Hits@20
# Run: 01, Epoch: 163, Loss: 0.7092, Valid: 6.82%, Test: 2.59%
# Hits@50
# Run: 01, Epoch: 163, Loss: 0.7092, Valid: 9.38%, Test: 4.17%
# Hits@100
# Run: 01, Epoch: 163, Loss: 0.7092, Valid: 11.84%, Test: 6.62%
# Hits@1000
# Run: 01, Epoch: 163, Loss: 0.7092, Valid: 36.60%, Test: 32.17%
# Hits@10000
# Run: 01, Epoch: 163, Loss: 0.7092, Valid: 78.78%, Test: 80.12%
# ---
# Hits@20
# Run: 01, Epoch: 164, Loss: 0.6929, Valid: 2.18%, Test: 2.59%
# Hits@50
# Run: 01, Epoch: 164, Loss: 0.6929, Valid: 3.79%, Test: 4.54%
# Hits@100
# Run: 01, Epoch: 164, Loss: 0.6929, Valid: 6.01%, Test: 7.27%
# Hits@1000
# Run: 01, Epoch: 164, Loss: 0.6929, Valid: 39.13%, Test: 33.91%
# Hits@10000
# Run: 01, Epoch: 164, Loss: 0.6929, Valid: 77.81%, Test: 79.95%
# ---
# Hits@20
# Run: 01, Epoch: 165, Loss: 0.6958, Valid: 4.96%, Test: 2.24%
# Hits@50
# Run: 01, Epoch: 165, Loss: 0.6958, Valid: 6.25%, Test: 3.24%
# Hits@100
# Run: 01, Epoch: 165, Loss: 0.6958, Valid: 8.08%, Test: 5.02%
# Hits@1000
# Run: 01, Epoch: 165, Loss: 0.6958, Valid: 26.94%, Test: 22.83%
# Hits@10000
# Run: 01, Epoch: 165, Loss: 0.6958, Valid: 76.71%, Test: 76.98%
# ---
# Hits@20
# Run: 01, Epoch: 166, Loss: 0.7111, Valid: 0.75%, Test: 1.42%
# Hits@50
# Run: 01, Epoch: 166, Loss: 0.7111, Valid: 1.65%, Test: 2.98%
# Hits@100
# Run: 01, Epoch: 166, Loss: 0.7111, Valid: 2.63%, Test: 4.86%
# Hits@1000
# Run: 01, Epoch: 166, Loss: 0.7111, Valid: 25.18%, Test: 31.64%
# Hits@10000
# Run: 01, Epoch: 166, Loss: 0.7111, Valid: 78.49%, Test: 79.72%
# ---
# Hits@20
# Run: 01, Epoch: 167, Loss: 0.7139, Valid: 0.77%, Test: 1.35%
# Hits@50
# Run: 01, Epoch: 167, Loss: 0.7139, Valid: 1.41%, Test: 2.29%
# Hits@100
# Run: 01, Epoch: 167, Loss: 0.7139, Valid: 2.81%, Test: 3.58%
# Hits@1000
# Run: 01, Epoch: 167, Loss: 0.7139, Valid: 18.09%, Test: 21.32%
# Hits@10000
# Run: 01, Epoch: 167, Loss: 0.7139, Valid: 80.03%, Test: 81.03%
# ---
# Hits@20
# Run: 01, Epoch: 168, Loss: 0.7207, Valid: 5.54%, Test: 3.01%
# Hits@50
# Run: 01, Epoch: 168, Loss: 0.7207, Valid: 6.99%, Test: 4.32%
# Hits@100
# Run: 01, Epoch: 168, Loss: 0.7207, Valid: 8.55%, Test: 7.39%
# Hits@1000
# Run: 01, Epoch: 168, Loss: 0.7207, Valid: 33.17%, Test: 38.68%
# Hits@10000
# Run: 01, Epoch: 168, Loss: 0.7207, Valid: 80.52%, Test: 80.35%
# ---
# Hits@20
# Run: 01, Epoch: 169, Loss: 0.7051, Valid: 2.51%, Test: 2.38%
# Hits@50
# Run: 01, Epoch: 169, Loss: 0.7051, Valid: 3.54%, Test: 3.83%
# Hits@100
# Run: 01, Epoch: 169, Loss: 0.7051, Valid: 5.22%, Test: 5.25%
# Hits@1000
# Run: 01, Epoch: 169, Loss: 0.7051, Valid: 30.84%, Test: 28.64%
# Hits@10000
# Run: 01, Epoch: 169, Loss: 0.7051, Valid: 80.23%, Test: 80.37%
# ---
# Hits@20
# Run: 01, Epoch: 170, Loss: 0.6959, Valid: 10.52%, Test: 2.69%
# Hits@50
# Run: 01, Epoch: 170, Loss: 0.6959, Valid: 12.38%, Test: 3.40%
# Hits@100
# Run: 01, Epoch: 170, Loss: 0.6959, Valid: 14.50%, Test: 4.73%
# Hits@1000
# Run: 01, Epoch: 170, Loss: 0.6959, Valid: 27.48%, Test: 17.54%
# Hits@10000
# Run: 01, Epoch: 170, Loss: 0.6959, Valid: 79.91%, Test: 79.84%
# ---
# Hits@20
# Run: 01, Epoch: 171, Loss: 0.6878, Valid: 3.16%, Test: 1.37%
# Hits@50
# Run: 01, Epoch: 171, Loss: 0.6878, Valid: 4.80%, Test: 3.29%
# Hits@100
# Run: 01, Epoch: 171, Loss: 0.6878, Valid: 6.22%, Test: 4.88%
# Hits@1000
# Run: 01, Epoch: 171, Loss: 0.6878, Valid: 26.29%, Test: 17.55%
# Hits@10000
# Run: 01, Epoch: 171, Loss: 0.6878, Valid: 79.26%, Test: 79.80%
# ---
# Hits@20
# Run: 01, Epoch: 172, Loss: 0.7001, Valid: 4.02%, Test: 3.89%
# Hits@50
# Run: 01, Epoch: 172, Loss: 0.7001, Valid: 5.72%, Test: 7.34%
# Hits@100
# Run: 01, Epoch: 172, Loss: 0.7001, Valid: 8.15%, Test: 12.04%
# Hits@1000
# Run: 01, Epoch: 172, Loss: 0.7001, Valid: 42.72%, Test: 37.56%
# Hits@10000
# Run: 01, Epoch: 172, Loss: 0.7001, Valid: 79.39%, Test: 79.91%
# ---
# Hits@20
# Run: 01, Epoch: 173, Loss: 0.7035, Valid: 3.58%, Test: 2.61%
# Hits@50
# Run: 01, Epoch: 173, Loss: 0.7035, Valid: 4.91%, Test: 3.97%
# Hits@100
# Run: 01, Epoch: 173, Loss: 0.7035, Valid: 6.66%, Test: 5.45%
# Hits@1000
# Run: 01, Epoch: 173, Loss: 0.7035, Valid: 22.74%, Test: 24.11%
# Hits@10000
# Run: 01, Epoch: 173, Loss: 0.7035, Valid: 79.16%, Test: 80.98%
# ---
# Hits@20
# Run: 01, Epoch: 174, Loss: 0.7187, Valid: 3.78%, Test: 2.28%
# Hits@50
# Run: 01, Epoch: 174, Loss: 0.7187, Valid: 4.99%, Test: 3.44%
# Hits@100
# Run: 01, Epoch: 174, Loss: 0.7187, Valid: 6.06%, Test: 4.68%
# Hits@1000
# Run: 01, Epoch: 174, Loss: 0.7187, Valid: 16.75%, Test: 14.72%
# Hits@10000
# Run: 01, Epoch: 174, Loss: 0.7187, Valid: 70.94%, Test: 71.59%
# ---
# Hits@20
# Run: 01, Epoch: 175, Loss: 0.7101, Valid: 4.34%, Test: 1.41%
# Hits@50
# Run: 01, Epoch: 175, Loss: 0.7101, Valid: 5.19%, Test: 2.02%
# Hits@100
# Run: 01, Epoch: 175, Loss: 0.7101, Valid: 6.08%, Test: 3.32%
# Hits@1000
# Run: 01, Epoch: 175, Loss: 0.7101, Valid: 16.39%, Test: 15.12%
# Hits@10000
# Run: 01, Epoch: 175, Loss: 0.7101, Valid: 75.09%, Test: 72.01%
# ---
# Hits@20
# Run: 01, Epoch: 176, Loss: 0.7051, Valid: 1.04%, Test: 1.93%
# Hits@50
# Run: 01, Epoch: 176, Loss: 0.7051, Valid: 1.97%, Test: 3.33%
# Hits@100
# Run: 01, Epoch: 176, Loss: 0.7051, Valid: 3.13%, Test: 5.54%
# Hits@1000
# Run: 01, Epoch: 176, Loss: 0.7051, Valid: 15.80%, Test: 19.63%
# Hits@10000
# Run: 01, Epoch: 176, Loss: 0.7051, Valid: 62.82%, Test: 71.13%
# ---
# Hits@20
# Run: 01, Epoch: 177, Loss: 0.7257, Valid: 2.49%, Test: 4.62%
# Hits@50
# Run: 01, Epoch: 177, Loss: 0.7257, Valid: 4.55%, Test: 6.85%
# Hits@100
# Run: 01, Epoch: 177, Loss: 0.7257, Valid: 6.75%, Test: 9.30%
# Hits@1000
# Run: 01, Epoch: 177, Loss: 0.7257, Valid: 25.29%, Test: 26.62%
# Hits@10000
# Run: 01, Epoch: 177, Loss: 0.7257, Valid: 75.32%, Test: 75.05%
# ---
# Hits@20
# Run: 01, Epoch: 178, Loss: 0.7242, Valid: 2.20%, Test: 3.58%
# Hits@50
# Run: 01, Epoch: 178, Loss: 0.7242, Valid: 3.63%, Test: 7.85%
# Hits@100
# Run: 01, Epoch: 178, Loss: 0.7242, Valid: 5.58%, Test: 13.20%
# Hits@1000
# Run: 01, Epoch: 178, Loss: 0.7242, Valid: 34.66%, Test: 35.63%
# Hits@10000
# Run: 01, Epoch: 178, Loss: 0.7242, Valid: 75.05%, Test: 75.07%
# ---
# Hits@20
# Run: 01, Epoch: 179, Loss: 0.7399, Valid: 1.59%, Test: 2.64%
# Hits@50
# Run: 01, Epoch: 179, Loss: 0.7399, Valid: 2.53%, Test: 4.12%
# Hits@100
# Run: 01, Epoch: 179, Loss: 0.7399, Valid: 4.47%, Test: 6.37%
# Hits@1000
# Run: 01, Epoch: 179, Loss: 0.7399, Valid: 23.08%, Test: 30.37%
# Hits@10000
# Run: 01, Epoch: 179, Loss: 0.7399, Valid: 75.95%, Test: 76.10%
# ---
# Hits@20
# Run: 01, Epoch: 180, Loss: 0.7491, Valid: 1.68%, Test: 2.93%
# Hits@50
# Run: 01, Epoch: 180, Loss: 0.7491, Valid: 3.36%, Test: 3.88%
# Hits@100
# Run: 01, Epoch: 180, Loss: 0.7491, Valid: 5.34%, Test: 5.43%
# Hits@1000
# Run: 01, Epoch: 180, Loss: 0.7491, Valid: 19.36%, Test: 21.80%
# Hits@10000
# Run: 01, Epoch: 180, Loss: 0.7491, Valid: 68.95%, Test: 72.67%
# ---
# Hits@20
# Run: 01, Epoch: 181, Loss: 0.7323, Valid: 1.92%, Test: 3.56%
# Hits@50
# Run: 01, Epoch: 181, Loss: 0.7323, Valid: 3.79%, Test: 5.64%
# Hits@100
# Run: 01, Epoch: 181, Loss: 0.7323, Valid: 5.80%, Test: 7.72%
# Hits@1000
# Run: 01, Epoch: 181, Loss: 0.7323, Valid: 21.90%, Test: 25.26%
# Hits@10000
# Run: 01, Epoch: 181, Loss: 0.7323, Valid: 73.59%, Test: 75.12%
# ---
# Hits@20
# Run: 01, Epoch: 182, Loss: 0.7370, Valid: 4.19%, Test: 4.05%
# Hits@50
# Run: 01, Epoch: 182, Loss: 0.7370, Valid: 5.69%, Test: 8.34%
# Hits@100
# Run: 01, Epoch: 182, Loss: 0.7370, Valid: 8.77%, Test: 12.91%
# Hits@1000
# Run: 01, Epoch: 182, Loss: 0.7370, Valid: 34.45%, Test: 42.70%
# Hits@10000
# Run: 01, Epoch: 182, Loss: 0.7370, Valid: 75.66%, Test: 75.73%
# ---
# Hits@20
# Run: 01, Epoch: 183, Loss: 0.7476, Valid: 2.25%, Test: 3.19%
# Hits@50
# Run: 01, Epoch: 183, Loss: 0.7476, Valid: 3.92%, Test: 4.91%
# Hits@100
# Run: 01, Epoch: 183, Loss: 0.7476, Valid: 5.98%, Test: 6.99%
# Hits@1000
# Run: 01, Epoch: 183, Loss: 0.7476, Valid: 19.59%, Test: 22.40%
# Hits@10000
# Run: 01, Epoch: 183, Loss: 0.7476, Valid: 72.54%, Test: 75.28%
# ---
# Hits@20
# Run: 01, Epoch: 184, Loss: 0.7266, Valid: 1.46%, Test: 3.70%
# Hits@50
# Run: 01, Epoch: 184, Loss: 0.7266, Valid: 4.07%, Test: 5.87%
# Hits@100
# Run: 01, Epoch: 184, Loss: 0.7266, Valid: 5.94%, Test: 8.18%
# Hits@1000
# Run: 01, Epoch: 184, Loss: 0.7266, Valid: 23.73%, Test: 28.86%
# Hits@10000
# Run: 01, Epoch: 184, Loss: 0.7266, Valid: 75.40%, Test: 75.51%
# ---
# Hits@20
# Run: 01, Epoch: 185, Loss: 0.7318, Valid: 2.77%, Test: 4.42%
# Hits@50
# Run: 01, Epoch: 185, Loss: 0.7318, Valid: 4.91%, Test: 6.60%
# Hits@100
# Run: 01, Epoch: 185, Loss: 0.7318, Valid: 8.20%, Test: 10.80%
# Hits@1000
# Run: 01, Epoch: 185, Loss: 0.7318, Valid: 36.37%, Test: 41.31%
# Hits@10000
# Run: 01, Epoch: 185, Loss: 0.7318, Valid: 76.53%, Test: 76.39%
# ---
# Hits@20
# Run: 01, Epoch: 186, Loss: 0.7651, Valid: 9.24%, Test: 5.37%
# Hits@50
# Run: 01, Epoch: 186, Loss: 0.7651, Valid: 11.87%, Test: 11.56%
# Hits@100
# Run: 01, Epoch: 186, Loss: 0.7651, Valid: 15.14%, Test: 18.27%
# Hits@1000
# Run: 01, Epoch: 186, Loss: 0.7651, Valid: 42.66%, Test: 41.41%
# Hits@10000
# Run: 01, Epoch: 186, Loss: 0.7651, Valid: 76.71%, Test: 76.20%
# ---
# Hits@20
# Run: 01, Epoch: 187, Loss: 0.7536, Valid: 2.17%, Test: 2.51%
# Hits@50
# Run: 01, Epoch: 187, Loss: 0.7536, Valid: 4.17%, Test: 4.34%
# Hits@100
# Run: 01, Epoch: 187, Loss: 0.7536, Valid: 6.27%, Test: 7.08%
# Hits@1000
# Run: 01, Epoch: 187, Loss: 0.7536, Valid: 26.74%, Test: 34.82%
# Hits@10000
# Run: 01, Epoch: 187, Loss: 0.7536, Valid: 72.77%, Test: 74.98%
# ---
# Hits@20
# Run: 01, Epoch: 188, Loss: 0.7579, Valid: 4.31%, Test: 3.33%
# Hits@50
# Run: 01, Epoch: 188, Loss: 0.7579, Valid: 6.36%, Test: 4.84%
# Hits@100
# Run: 01, Epoch: 188, Loss: 0.7579, Valid: 8.26%, Test: 6.93%
# Hits@1000
# Run: 01, Epoch: 188, Loss: 0.7579, Valid: 21.14%, Test: 23.58%
# Hits@10000
# Run: 01, Epoch: 188, Loss: 0.7579, Valid: 71.49%, Test: 74.79%
# ---
# Hits@20
# Run: 01, Epoch: 189, Loss: 0.7536, Valid: 1.28%, Test: 3.29%
# Hits@50
# Run: 01, Epoch: 189, Loss: 0.7536, Valid: 2.09%, Test: 4.74%
# Hits@100
# Run: 01, Epoch: 189, Loss: 0.7536, Valid: 3.75%, Test: 6.99%
# Hits@1000
# Run: 01, Epoch: 189, Loss: 0.7536, Valid: 19.41%, Test: 22.24%
# Hits@10000
# Run: 01, Epoch: 189, Loss: 0.7536, Valid: 61.36%, Test: 71.18%
# ---
# Hits@20
# Run: 01, Epoch: 190, Loss: 0.7478, Valid: 4.80%, Test: 4.23%
# Hits@50
# Run: 01, Epoch: 190, Loss: 0.7478, Valid: 7.56%, Test: 8.96%
# Hits@100
# Run: 01, Epoch: 190, Loss: 0.7478, Valid: 10.55%, Test: 13.47%
# Hits@1000
# Run: 01, Epoch: 190, Loss: 0.7478, Valid: 35.11%, Test: 39.02%
# Hits@10000
# Run: 01, Epoch: 190, Loss: 0.7478, Valid: 76.26%, Test: 75.94%
# ---
# Hits@20
# Run: 01, Epoch: 191, Loss: 0.7297, Valid: 1.56%, Test: 1.61%
# Hits@50
# Run: 01, Epoch: 191, Loss: 0.7297, Valid: 2.44%, Test: 3.57%
# Hits@100
# Run: 01, Epoch: 191, Loss: 0.7297, Valid: 3.72%, Test: 6.29%
# Hits@1000
# Run: 01, Epoch: 191, Loss: 0.7297, Valid: 21.00%, Test: 26.32%
# Hits@10000
# Run: 01, Epoch: 191, Loss: 0.7297, Valid: 77.09%, Test: 76.96%
# ---
# Hits@20
# Run: 01, Epoch: 192, Loss: 0.7329, Valid: 2.38%, Test: 3.01%
# Hits@50
# Run: 01, Epoch: 192, Loss: 0.7329, Valid: 4.25%, Test: 5.36%
# Hits@100
# Run: 01, Epoch: 192, Loss: 0.7329, Valid: 6.24%, Test: 8.16%
# Hits@1000
# Run: 01, Epoch: 192, Loss: 0.7329, Valid: 25.25%, Test: 30.32%
# Hits@10000
# Run: 01, Epoch: 192, Loss: 0.7329, Valid: 76.30%, Test: 75.95%
# ---
# Hits@20
# Run: 01, Epoch: 193, Loss: 0.7607, Valid: 3.14%, Test: 2.86%
# Hits@50
# Run: 01, Epoch: 193, Loss: 0.7607, Valid: 5.78%, Test: 4.54%
# Hits@100
# Run: 01, Epoch: 193, Loss: 0.7607, Valid: 8.67%, Test: 6.99%
# Hits@1000
# Run: 01, Epoch: 193, Loss: 0.7607, Valid: 27.34%, Test: 29.22%
# Hits@10000
# Run: 01, Epoch: 193, Loss: 0.7607, Valid: 76.02%, Test: 76.00%
# ---
# Hits@20
# Run: 01, Epoch: 194, Loss: 0.7436, Valid: 5.16%, Test: 6.34%
# Hits@50
# Run: 01, Epoch: 194, Loss: 0.7436, Valid: 8.48%, Test: 11.05%
# Hits@100
# Run: 01, Epoch: 194, Loss: 0.7436, Valid: 11.94%, Test: 16.88%
# Hits@1000
# Run: 01, Epoch: 194, Loss: 0.7436, Valid: 39.16%, Test: 39.23%
# Hits@10000
# Run: 01, Epoch: 194, Loss: 0.7436, Valid: 76.04%, Test: 75.31%
# ---
# Hits@20
# Run: 01, Epoch: 195, Loss: 0.7424, Valid: 5.27%, Test: 4.18%
# Hits@50
# Run: 01, Epoch: 195, Loss: 0.7424, Valid: 7.05%, Test: 7.30%
# Hits@100
# Run: 01, Epoch: 195, Loss: 0.7424, Valid: 10.05%, Test: 11.20%
# Hits@1000
# Run: 01, Epoch: 195, Loss: 0.7424, Valid: 31.45%, Test: 34.73%
# Hits@10000
# Run: 01, Epoch: 195, Loss: 0.7424, Valid: 76.11%, Test: 75.51%
# ---
# Hits@20
# Run: 01, Epoch: 196, Loss: 0.7516, Valid: 0.94%, Test: 0.99%
# Hits@50
# Run: 01, Epoch: 196, Loss: 0.7516, Valid: 1.53%, Test: 1.97%
# Hits@100
# Run: 01, Epoch: 196, Loss: 0.7516, Valid: 2.41%, Test: 3.12%
# Hits@1000
# Run: 01, Epoch: 196, Loss: 0.7516, Valid: 14.86%, Test: 20.63%
# Hits@10000
# Run: 01, Epoch: 196, Loss: 0.7516, Valid: 66.80%, Test: 70.89%
# ---
# Hits@20
# Run: 01, Epoch: 197, Loss: 0.7385, Valid: 5.07%, Test: 3.90%
# Hits@50
# Run: 01, Epoch: 197, Loss: 0.7385, Valid: 6.17%, Test: 5.47%
# Hits@100
# Run: 01, Epoch: 197, Loss: 0.7385, Valid: 7.64%, Test: 7.85%
# Hits@1000
# Run: 01, Epoch: 197, Loss: 0.7385, Valid: 24.01%, Test: 24.93%
# Hits@10000
# Run: 01, Epoch: 197, Loss: 0.7385, Valid: 73.11%, Test: 76.14%
# ---
# Hits@20
# Run: 01, Epoch: 198, Loss: 0.7348, Valid: 4.92%, Test: 4.24%
# Hits@50
# Run: 01, Epoch: 198, Loss: 0.7348, Valid: 7.08%, Test: 5.86%
# Hits@100
# Run: 01, Epoch: 198, Loss: 0.7348, Valid: 8.58%, Test: 9.20%
# Hits@1000
# Run: 01, Epoch: 198, Loss: 0.7348, Valid: 24.19%, Test: 30.99%
# Hits@10000
# Run: 01, Epoch: 198, Loss: 0.7348, Valid: 77.35%, Test: 76.34%
# ---
# Hits@20
# Run: 01, Epoch: 199, Loss: 0.7260, Valid: 3.43%, Test: 2.30%
# Hits@50
# Run: 01, Epoch: 199, Loss: 0.7260, Valid: 4.81%, Test: 4.55%
# Hits@100
# Run: 01, Epoch: 199, Loss: 0.7260, Valid: 6.40%, Test: 7.95%
# Hits@1000
# Run: 01, Epoch: 199, Loss: 0.7260, Valid: 23.90%, Test: 32.75%
# Hits@10000
# Run: 01, Epoch: 199, Loss: 0.7260, Valid: 76.20%, Test: 75.74%
# ---
# Hits@20
# Run: 01, Epoch: 200, Loss: 0.7280, Valid: 2.32%, Test: 4.07%
# Hits@50
# Run: 01, Epoch: 200, Loss: 0.7280, Valid: 4.11%, Test: 6.11%
# Hits@100
# Run: 01, Epoch: 200, Loss: 0.7280, Valid: 6.41%, Test: 8.46%
# Hits@1000
# Run: 01, Epoch: 200, Loss: 0.7280, Valid: 22.50%, Test: 25.58%
# Hits@10000
# Run: 01, Epoch: 200, Loss: 0.7280, Valid: 76.17%, Test: 75.58%
# ---

# %%
hits_10000 = loggers["Hits@10000"].results[0]
hits_1000 = loggers["Hits@1000"].results[0]
hits_100 = loggers["Hits@100"].results[0]
hits_50 = loggers["Hits@50"].results[0]
hits_20 = loggers["Hits@20"].results[0]

df_10000 = pd.DataFrame(hits_10000)
df_1000 = pd.DataFrame(hits_1000)
df_100 = pd.DataFrame(hits_100)
df_50 = pd.DataFrame(hits_50)
df_20 = pd.DataFrame(hits_20)

df_10000.to_csv("NN_4267_SPD_features_hits_10000.csv")
df_1000.to_csv("NN_4267_SPD_features_hits_1000.csv")
df_100.to_csv("NN_4267_SPD_features_hits_100.csv")
df_50.to_csv("NN_4267_SPD_features_hits_50.csv")
df_20.to_csv("NN_4267_SPD_features_hits_20.csv")
