# %% [markdown]
# #### Installation of prereqs

# %%
import torch

# !pip install ogb

def format_pytorch_version(version):
  return version.split('+')[0]

TORCH_version = torch.__version__
TORCH = format_pytorch_version(TORCH_version)

def format_cuda_version(version):
  return 'cu' + version.replace('.', '')

CUDA_version = torch.version.cuda
CUDA = format_cuda_version(CUDA_version)

# !pip install torch-scatter     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse      -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-cluster     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric

# %% [markdown]
# #### Imports

# %%
import random
import networkx as nx

import torch
from torch.utils.data import DataLoader
from torch_geometric.utils import negative_sampling

from ogb.linkproppred import PygLinkPropPredDataset, Evaluator

import pandas as pd

from helpers import *

# %% [markdown]
# #### Functions for train and test

# %%
def train(model, predictor, edge_attr, x, emb_ea, adj_t, split_edge, optimizer, batch_size):
    edge_index = adj_t

    model.train()
    predictor.train()

    pos_train_edge = split_edge['train']['edge'].to(x.device)

    total_loss = total_examples = 0
    for perm in DataLoader(range(pos_train_edge.size(0)), batch_size, shuffle=True):
        optimizer.zero_grad()

        h = model(x, adj_t, edge_attr, emb_ea)

        # Get positive loss
        edge = pos_train_edge[perm].t()
        pos_out = predictor(h[edge[0]], h[edge[1]])
        pos_loss = -torch.log(pos_out + 1e-15).mean()

        # Get negative loss (Sample using torch_geometric.utils.negative_sampling)
        edge = negative_sampling(edge_index, num_nodes=x.size(0),
                                 num_neg_samples=perm.size(0), method='dense')
        neg_out = predictor(h[edge[0]], h[edge[1]])
        neg_loss = -torch.log(1 - neg_out + 1e-15).mean()

        # Get total loss and gradients
        loss = pos_loss + neg_loss
        loss.backward()

        # Clip gradient (Limit maximum l2 norm of gradients to 1)
        torch.nn.utils.clip_grad_norm_(x, 1.0)
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        torch.nn.utils.clip_grad_norm_(predictor.parameters(), 1.0)

        optimizer.step()

        num_examples = pos_out.size(0)
        total_loss += loss.item() * num_examples
        total_examples += num_examples

    return total_loss / total_examples


@torch.no_grad()
def test(model, predictor, edge_attr, x, emb_ea, adj_t, split_edge, evaluator, batch_size):
    model.eval()
    predictor.eval()

    h = model(x, adj_t, edge_attr, emb_ea)

    pos_valid_edge = split_edge['valid']['edge'].to(x.device)
    neg_valid_edge = split_edge['valid']['edge_neg'].to(x.device)
    pos_test_edge = split_edge['test']['edge'].to(x.device)
    neg_test_edge = split_edge['test']['edge_neg'].to(x.device)

    pos_valid_preds = []
    for perm in DataLoader(range(pos_valid_edge.size(0)), batch_size):
        edge = pos_valid_edge[perm].t()
        pos_valid_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    pos_valid_pred = torch.cat(pos_valid_preds, dim=0)

    neg_valid_preds = []
    for perm in DataLoader(range(neg_valid_edge.size(0)), batch_size):
        edge = neg_valid_edge[perm].t()
        neg_valid_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    neg_valid_pred = torch.cat(neg_valid_preds, dim=0)

    pos_test_preds = []
    for perm in DataLoader(range(pos_test_edge.size(0)), batch_size):
        edge = pos_test_edge[perm].t()
        pos_test_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    pos_test_pred = torch.cat(pos_test_preds, dim=0)

    neg_test_preds = []
    for perm in DataLoader(range(neg_test_edge.size(0)), batch_size):
        edge = neg_test_edge[perm].t()
        neg_test_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    neg_test_pred = torch.cat(neg_test_preds, dim=0)

    results = {}
    for K in [20, 50, 100]:
        evaluator.K = K
        valid_hits = evaluator.eval({
            'y_pred_pos': pos_valid_pred,
            'y_pred_neg': neg_valid_pred,
        })[f'hits@{K}']
        test_hits = evaluator.eval({
            'y_pred_pos': pos_test_pred,
            'y_pred_neg': neg_test_pred,
        })[f'hits@{K}']

        results[f'Hits@{K}'] = (valid_hits, test_hits)

    return results

# %% [markdown]
# #### Set up model

# %%
# Model and training parameters
args={
      "device":0, "num_layers":2, "num_samples":100, "node_emb":256, 
      "hidden_channels":256, "dropout":0.3, "batch_size":64 * 1024,
      "lr":0.003, "epochs":200, "log_steps":1, "eval_steps":1, 
      "runs":1
      }

# %%
# Set device
device = f'cuda:{args["device"]}' if torch.cuda.is_available() else 'cpu'

# Load OGB Dataset
dataset = PygLinkPropPredDataset(name='ogbl-ddi')
data = dataset[0]
edge_index = data.edge_index.to(device)
split_edge = dataset.get_edge_split()

# Load model
model = GraphSAGE(args["node_emb"], args["hidden_channels"], args["hidden_channels"],
                  args["num_layers"], args["dropout"]).to(device)
emb = torch.nn.Embedding(data["num_nodes"], args["node_emb"]).to(device)
emb_ea = torch.nn.Embedding(args["num_samples"], args["node_emb"]).to(device)
predictor = LinkPredictor(args["hidden_channels"], args["hidden_channels"], 1,
                          args["num_layers"]+1, args["dropout"]).to(device)

print('Number of parameters:',
      sum(p.numel() for p in list(model.parameters()) +
      list(predictor.parameters()) + list(emb.parameters()) + list(emb_ea.parameters())))
# Out:
# Number of parameters: 1512449

# %% [markdown]
# #### Generate Laplacian features

# %%
# Set dimensionality k of our Laplacian feature vectors
k = 100 

# Get edge list
train_edges = dataset[0]["edge_index"]
edge_list = train_edges.transpose(0,1 ).tolist()

# Make graph and get adjacency
G = nx.from_edgelist(edge_list)
G.number_of_nodes()
A = nx.to_numpy_matrix(G) 
L = nx.normalized_laplacian_matrix(G) 

# Get eigen decomposition
L_dense = L.todense()
L_tens = torch.tensor(L_dense)
L_cud = L_tens.to(device)
lamb, U = torch.linalg.eig(L_cud)
lamb_real, U_real = torch.real(lamb), torch.real(U)

# Sort eigenvectors after eigenvalues in descending order
lamb_real_sorted, indices = torch.sort(lamb_real)
U_sorted = U_real[indices]

eigen_features = U_sorted[:, :k]
eigen_features.to(device)
eigen_features = eigen_features.float()

# edge_attr: For all edges in the entire graph, collect the laplacian node eigenfeatures for each node in each pair
edge_attr = eigen_features[edge_index, :]

# edge_attr: We now create an edge feature averaging over the node eigenfeatures for each edge (Two nodes per edge)
edge_attr = edge_attr.mean(0)

# To tensor
edge_attr = torch.tensor(edge_attr).to(device)

# edge_attr: Min max normalize
a_max = torch.max(edge_attr, dim=0, keepdim=True)[0]
a_min = torch.min(edge_attr, dim=0, keepdim=True)[0]
edge_attr = (edge_attr - a_min) / (a_max - a_min + 1e-6)

# %% [markdown]
# #### Set up for training

# %%
# Evaluator
evaluator = Evaluator(name='ogbl-ddi')
loggers = {
    'Hits@20': Logger(args["runs"], args),
    'Hits@50': Logger(args["runs"], args),
    'Hits@100': Logger(args["runs"], args),
}

# %%
# Initialize node embeddings
run = 0
random.seed(run)
torch.manual_seed(run)
torch.nn.init.xavier_uniform_(emb.weight)
torch.nn.init.xavier_uniform_(emb_ea.weight)
model.reset_parameters()
predictor.reset_parameters()
optimizer = torch.optim.Adam(
    list(model.parameters()) + list(emb.parameters()) +
    list(emb_ea.parameters()) + list(predictor.parameters()), lr=args["lr"])

# %% [markdown]
# #### Train

# %%
# Add to device
edge_index = edge_index.to(device)
emb = emb.to(device)
emb_ea = emb_ea.to(device)
model = model.to(device)
predictor = predictor.to(device)

# Train
for epoch in range(1, 1 + args["epochs"]):
    loss = train(model, predictor, edge_attr, emb.weight, emb_ea.weight, edge_index, split_edge,
                  optimizer, args["batch_size"])
    
    # Test
    if epoch % args["eval_steps"] == 0:
        results = test(model, predictor, edge_attr, emb.weight, emb_ea.weight, edge_index, split_edge,
                        evaluator, args["batch_size"])

        # Logging and prints 
        for key, result in results.items():
            loggers[key].add_result(run, result)
        if epoch % args["log_steps"] == 0:
            for key, result in results.items():
                valid_hits, test_hits = result
                print(key)
                print(f'Run: {run + 1:02d}, '
                      f'Epoch: {epoch:02d}, '
                      f'Loss: {loss:.4f}, '
                      f'Valid: {100 * valid_hits:.2f}%, '
                      f'Test: {100 * test_hits:.2f}%')
            print('---')
for key in loggers.keys():
    print(key)
    loggers[key].print_statistics(run)
# Out:
# Hits@20
# Run: 01, Epoch: 01, Loss: 1.3083, Valid: 0.98%, Test: 1.18%
# Hits@50
# Run: 01, Epoch: 01, Loss: 1.3083, Valid: 1.51%, Test: 1.81%
# Hits@100
# Run: 01, Epoch: 01, Loss: 1.3083, Valid: 2.61%, Test: 3.07%
# ---
# Hits@20
# Run: 01, Epoch: 02, Loss: 0.9302, Valid: 1.67%, Test: 2.57%
# Hits@50
# Run: 01, Epoch: 02, Loss: 0.9302, Valid: 2.77%, Test: 3.97%
# Hits@100
# Run: 01, Epoch: 02, Loss: 0.9302, Valid: 4.21%, Test: 5.93%
# ---
# Hits@20
# Run: 01, Epoch: 03, Loss: 0.8228, Valid: 2.05%, Test: 1.87%
# Hits@50
# Run: 01, Epoch: 03, Loss: 0.8228, Valid: 5.10%, Test: 6.12%
# Hits@100
# Run: 01, Epoch: 03, Loss: 0.8228, Valid: 8.23%, Test: 8.68%
# ---
# Hits@20
# Run: 01, Epoch: 04, Loss: 0.7273, Valid: 3.78%, Test: 5.36%
# Hits@50
# Run: 01, Epoch: 04, Loss: 0.7273, Valid: 6.66%, Test: 7.65%
# Hits@100
# Run: 01, Epoch: 04, Loss: 0.7273, Valid: 9.49%, Test: 10.42%
# ---
# Hits@20
# Run: 01, Epoch: 05, Loss: 0.6703, Valid: 9.94%, Test: 6.66%
# Hits@50
# Run: 01, Epoch: 05, Loss: 0.6703, Valid: 13.16%, Test: 11.49%
# Hits@100
# Run: 01, Epoch: 05, Loss: 0.6703, Valid: 16.10%, Test: 16.15%
# ---
# Hits@20
# Run: 01, Epoch: 06, Loss: 0.6240, Valid: 11.16%, Test: 3.68%
# Hits@50
# Run: 01, Epoch: 06, Loss: 0.6240, Valid: 13.71%, Test: 7.65%
# Hits@100
# Run: 01, Epoch: 06, Loss: 0.6240, Valid: 16.68%, Test: 13.04%
# ---
# Hits@20
# Run: 01, Epoch: 07, Loss: 0.5872, Valid: 13.12%, Test: 11.48%
# Hits@50
# Run: 01, Epoch: 07, Loss: 0.5872, Valid: 18.61%, Test: 15.11%
# Hits@100
# Run: 01, Epoch: 07, Loss: 0.5872, Valid: 23.11%, Test: 20.02%
# ---
# Hits@20
# Run: 01, Epoch: 08, Loss: 0.5561, Valid: 15.69%, Test: 12.70%
# Hits@50
# Run: 01, Epoch: 08, Loss: 0.5561, Valid: 22.17%, Test: 19.57%
# Hits@100
# Run: 01, Epoch: 08, Loss: 0.5561, Valid: 27.79%, Test: 25.71%
# ---
# Hits@20
# Run: 01, Epoch: 09, Loss: 0.5275, Valid: 16.04%, Test: 6.33%
# Hits@50
# Run: 01, Epoch: 09, Loss: 0.5275, Valid: 20.39%, Test: 10.07%
# Hits@100
# Run: 01, Epoch: 09, Loss: 0.5275, Valid: 25.02%, Test: 13.45%
# ---
# Hits@20
# Run: 01, Epoch: 10, Loss: 0.5037, Valid: 22.73%, Test: 11.73%
# Hits@50
# Run: 01, Epoch: 10, Loss: 0.5037, Valid: 30.57%, Test: 24.80%
# Hits@100
# Run: 01, Epoch: 10, Loss: 0.5037, Valid: 35.68%, Test: 34.11%
# ---
# Hits@20
# Run: 01, Epoch: 11, Loss: 0.4832, Valid: 20.26%, Test: 10.54%
# Hits@50
# Run: 01, Epoch: 11, Loss: 0.4832, Valid: 27.28%, Test: 20.41%
# Hits@100
# Run: 01, Epoch: 11, Loss: 0.4832, Valid: 33.02%, Test: 27.02%
# ---
# Hits@20
# Run: 01, Epoch: 12, Loss: 0.4632, Valid: 12.51%, Test: 9.94%
# Hits@50
# Run: 01, Epoch: 12, Loss: 0.4632, Valid: 22.50%, Test: 20.37%
# Hits@100
# Run: 01, Epoch: 12, Loss: 0.4632, Valid: 29.26%, Test: 28.05%
# ---
# Hits@20
# Run: 01, Epoch: 13, Loss: 0.4520, Valid: 13.13%, Test: 12.76%
# Hits@50
# Run: 01, Epoch: 13, Loss: 0.4520, Valid: 22.20%, Test: 19.66%
# Hits@100
# Run: 01, Epoch: 13, Loss: 0.4520, Valid: 29.56%, Test: 27.04%
# ---
# Hits@20
# Run: 01, Epoch: 14, Loss: 0.4353, Valid: 10.04%, Test: 9.81%
# Hits@50
# Run: 01, Epoch: 14, Loss: 0.4353, Valid: 22.14%, Test: 17.45%
# Hits@100
# Run: 01, Epoch: 14, Loss: 0.4353, Valid: 30.88%, Test: 26.18%
# ---
# Hits@20
# Hits@20
# Run: 01, Epoch: 25, Loss: 0.3062, Valid: 28.27%, Test: 16.80%
# Hits@50
# Run: 01, Epoch: 25, Loss: 0.3062, Valid: 36.80%, Test: 27.71%
# Hits@100
# Run: 01, Epoch: 25, Loss: 0.3062, Valid: 44.18%, Test: 38.14%
# ---
# Hits@20
# Run: 01, Epoch: 26, Loss: 0.3027, Valid: 29.15%, Test: 18.91%
# Hits@50
# Run: 01, Epoch: 26, Loss: 0.3027, Valid: 35.62%, Test: 26.60%
# Hits@100
# Run: 01, Epoch: 26, Loss: 0.3027, Valid: 44.77%, Test: 36.42%
# ---
# Hits@20
# Run: 01, Epoch: 27, Loss: 0.2975, Valid: 29.32%, Test: 14.50%
# Hits@50
# Run: 01, Epoch: 27, Loss: 0.2975, Valid: 41.45%, Test: 23.40%
# Hits@100
# Run: 01, Epoch: 27, Loss: 0.2975, Valid: 49.95%, Test: 34.83%
# ---
# Hits@20
# Run: 01, Epoch: 28, Loss: 0.2902, Valid: 32.59%, Test: 14.39%
# Hits@50
# Run: 01, Epoch: 28, Loss: 0.2902, Valid: 43.12%, Test: 25.14%
# Hits@100
# Run: 01, Epoch: 28, Loss: 0.2902, Valid: 50.67%, Test: 35.28%
# ---
# Hits@20
# Run: 01, Epoch: 29, Loss: 0.2866, Valid: 28.71%, Test: 19.67%
# Hits@50
# Run: 01, Epoch: 29, Loss: 0.2866, Valid: 39.47%, Test: 26.59%
# Hits@100
# Run: 01, Epoch: 29, Loss: 0.2866, Valid: 48.78%, Test: 38.33%
# ---
# Hits@20
# Run: 01, Epoch: 30, Loss: 0.2804, Valid: 32.31%, Test: 12.55%
# Hits@50
# Run: 01, Epoch: 30, Loss: 0.2804, Valid: 41.90%, Test: 18.59%
# Hits@100
# Run: 01, Epoch: 30, Loss: 0.2804, Valid: 49.87%, Test: 27.34%
# ---
# Hits@20
# Run: 01, Epoch: 31, Loss: 0.2762, Valid: 34.47%, Test: 14.95%
# Hits@50
# Run: 01, Epoch: 31, Loss: 0.2762, Valid: 46.07%, Test: 27.45%
# Hits@100
# Run: 01, Epoch: 31, Loss: 0.2762, Valid: 54.54%, Test: 36.30%
# ---
# Hits@20
# Run: 01, Epoch: 32, Loss: 0.2732, Valid: 32.94%, Test: 17.54%
# Hits@50
# Run: 01, Epoch: 32, Loss: 0.2732, Valid: 43.95%, Test: 26.03%
# Hits@100
# Run: 01, Epoch: 32, Loss: 0.2732, Valid: 51.05%, Test: 36.74%
# ---
# Hits@20
# Run: 01, Epoch: 33, Loss: 0.2674, Valid: 29.81%, Test: 16.87%
# Hits@50
# Run: 01, Epoch: 33, Loss: 0.2674, Valid: 43.04%, Test: 26.98%
# Hits@100
# Run: 01, Epoch: 33, Loss: 0.2674, Valid: 51.62%, Test: 38.46%
# ---
# Hits@20
# Run: 01, Epoch: 34, Loss: 0.2644, Valid: 31.72%, Test: 16.25%
# Hits@50
# Run: 01, Epoch: 34, Loss: 0.2644, Valid: 43.76%, Test: 23.27%
# Hits@100
# Run: 01, Epoch: 34, Loss: 0.2644, Valid: 52.13%, Test: 33.65%
# ---
# Hits@20
# Run: 01, Epoch: 35, Loss: 0.2620, Valid: 34.78%, Test: 19.07%
# Hits@50
# Run: 01, Epoch: 35, Loss: 0.2620, Valid: 46.56%, Test: 23.81%
# Hits@100
# Run: 01, Epoch: 35, Loss: 0.2620, Valid: 53.43%, Test: 33.60%
# ---
# Hits@20
# Run: 01, Epoch: 36, Loss: 0.2602, Valid: 29.88%, Test: 15.68%
# Hits@50
# Run: 01, Epoch: 36, Loss: 0.2602, Valid: 43.18%, Test: 26.00%
# Hits@100
# Run: 01, Epoch: 36, Loss: 0.2602, Valid: 49.28%, Test: 36.86%
# ---
# Hits@20
# Run: 01, Epoch: 37, Loss: 0.2543, Valid: 32.07%, Test: 15.41%
# Hits@50
# Run: 01, Epoch: 37, Loss: 0.2543, Valid: 46.96%, Test: 24.12%
# Hits@100
# Run: 01, Epoch: 37, Loss: 0.2543, Valid: 53.53%, Test: 39.66%
# ---
# Hits@20
# Run: 01, Epoch: 38, Loss: 0.2507, Valid: 37.88%, Test: 15.41%
# Hits@50
# Run: 01, Epoch: 38, Loss: 0.2507, Valid: 46.80%, Test: 28.35%
# Hits@100
# Run: 01, Epoch: 38, Loss: 0.2507, Valid: 54.37%, Test: 41.63%
# ---
# Hits@20
# Run: 01, Epoch: 39, Loss: 0.2489, Valid: 31.43%, Test: 12.94%
# Hits@50
# Run: 01, Epoch: 39, Loss: 0.2489, Valid: 45.46%, Test: 24.96%
# Hits@100
# Run: 01, Epoch: 39, Loss: 0.2489, Valid: 53.99%, Test: 35.91%
# ---
# Hits@20
# Run: 01, Epoch: 40, Loss: 0.2466, Valid: 33.77%, Test: 12.69%
# Hits@50
# Run: 01, Epoch: 40, Loss: 0.2466, Valid: 45.77%, Test: 24.06%
# Hits@100
# Run: 01, Epoch: 40, Loss: 0.2466, Valid: 53.37%, Test: 37.93%
# ---
# Hits@20
# Run: 01, Epoch: 41, Loss: 0.2432, Valid: 36.50%, Test: 13.32%
# Hits@50
# Run: 01, Epoch: 41, Loss: 0.2432, Valid: 48.79%, Test: 22.62%
# Hits@100
# Run: 01, Epoch: 41, Loss: 0.2432, Valid: 57.22%, Test: 33.05%
# ---
# Hits@20
# Run: 01, Epoch: 42, Loss: 0.2396, Valid: 41.44%, Test: 13.05%
# Hits@50
# Run: 01, Epoch: 42, Loss: 0.2396, Valid: 48.32%, Test: 25.34%
# Hits@100
# Run: 01, Epoch: 42, Loss: 0.2396, Valid: 55.49%, Test: 39.09%
# ---
# Hits@20
# Run: 01, Epoch: 43, Loss: 0.2378, Valid: 41.68%, Test: 14.45%
# Hits@50
# Run: 01, Epoch: 43, Loss: 0.2378, Valid: 52.65%, Test: 23.98%
# Hits@100
# Run: 01, Epoch: 43, Loss: 0.2378, Valid: 59.02%, Test: 37.56%
# ---
# Hits@20
# Run: 01, Epoch: 44, Loss: 0.2352, Valid: 37.21%, Test: 11.58%
# Hits@50
# Run: 01, Epoch: 44, Loss: 0.2352, Valid: 49.26%, Test: 20.60%
# Hits@100
# Run: 01, Epoch: 54, Loss: 0.2153, Valid: 61.80%, Test: 41.52%
# ---
# Hits@20
# Run: 01, Epoch: 55, Loss: 0.2146, Valid: 44.69%, Test: 8.87%
# Hits@50
# Run: 01, Epoch: 55, Loss: 0.2146, Valid: 59.01%, Test: 25.23%
# Hits@100
# Run: 01, Epoch: 55, Loss: 0.2146, Valid: 64.17%, Test: 46.11%
# ---
# Hits@20
# Run: 01, Epoch: 56, Loss: 0.2114, Valid: 51.64%, Test: 8.69%
# Hits@50
# Run: 01, Epoch: 56, Loss: 0.2114, Valid: 58.34%, Test: 31.08%
# Hits@100
# Run: 01, Epoch: 56, Loss: 0.2114, Valid: 63.72%, Test: 55.40%
# ---
# Hits@20
# Run: 01, Epoch: 57, Loss: 0.2102, Valid: 49.18%, Test: 6.26%
# Hits@50
# Run: 01, Epoch: 57, Loss: 0.2102, Valid: 56.93%, Test: 27.79%
# Hits@100
# Run: 01, Epoch: 57, Loss: 0.2102, Valid: 64.03%, Test: 42.88%
# ---
# Hits@20
# Run: 01, Epoch: 58, Loss: 0.2102, Valid: 52.89%, Test: 7.30%
# Hits@50
# Run: 01, Epoch: 58, Loss: 0.2102, Valid: 61.01%, Test: 25.36%
# Hits@100
# Run: 01, Epoch: 58, Loss: 0.2102, Valid: 64.74%, Test: 58.99%
# ---
# Hits@20
# Run: 01, Epoch: 59, Loss: 0.2086, Valid: 47.39%, Test: 4.47%
# Hits@50
# Run: 01, Epoch: 59, Loss: 0.2086, Valid: 59.78%, Test: 14.49%
# Hits@100
# Run: 01, Epoch: 59, Loss: 0.2086, Valid: 64.54%, Test: 36.68%
# ---
# Hits@20
# Run: 01, Epoch: 60, Loss: 0.2073, Valid: 42.72%, Test: 4.83%
# Hits@50
# Run: 01, Epoch: 60, Loss: 0.2073, Valid: 55.43%, Test: 21.68%
# Hits@100
# Run: 01, Epoch: 60, Loss: 0.2073, Valid: 62.17%, Test: 44.64%
# ---
# Hits@20
# Run: 01, Epoch: 61, Loss: 0.2074, Valid: 49.37%, Test: 7.41%
# Hits@50
# Run: 01, Epoch: 61, Loss: 0.2074, Valid: 60.11%, Test: 25.70%
# Hits@100
# Run: 01, Epoch: 61, Loss: 0.2074, Valid: 64.69%, Test: 48.39%
# ---
# Hits@20
# Run: 01, Epoch: 62, Loss: 0.2050, Valid: 46.02%, Test: 16.27%
# Hits@50
# Run: 01, Epoch: 62, Loss: 0.2050, Valid: 61.24%, Test: 32.85%
# Hits@100
# Run: 01, Epoch: 62, Loss: 0.2050, Valid: 65.43%, Test: 54.49%
# ---
# Hits@20
# Run: 01, Epoch: 63, Loss: 0.2029, Valid: 48.55%, Test: 11.14%
# Hits@50
# Run: 01, Epoch: 63, Loss: 0.2029, Valid: 60.86%, Test: 34.58%
# Hits@100
# Run: 01, Epoch: 63, Loss: 0.2029, Valid: 65.45%, Test: 64.76%
# ---
# Hits@20
# Run: 01, Epoch: 64, Loss: 0.2028, Valid: 42.03%, Test: 14.67%
# Hits@50
# Run: 01, Epoch: 64, Loss: 0.2028, Valid: 59.06%, Test: 40.51%
# Run: 01, Epoch: 74, Loss: 0.1925, Valid: 60.84%, Test: 27.17%
# Hits@100
# Run: 01, Epoch: 74, Loss: 0.1925, Valid: 66.60%, Test: 65.30%
# ---
# Hits@20
# Run: 01, Epoch: 75, Loss: 0.1935, Valid: 46.99%, Test: 9.61%
# Hits@50
# Run: 01, Epoch: 75, Loss: 0.1935, Valid: 62.52%, Test: 29.66%
# Hits@100
# Run: 01, Epoch: 75, Loss: 0.1935, Valid: 67.35%, Test: 68.27%
# ---
# Hits@20
# Run: 01, Epoch: 76, Loss: 0.1912, Valid: 47.12%, Test: 19.87%
# Hits@50
# Run: 01, Epoch: 76, Loss: 0.1912, Valid: 62.42%, Test: 52.96%
# Hits@100
# Run: 01, Epoch: 76, Loss: 0.1912, Valid: 66.53%, Test: 75.26%
# ---
# Hits@20
# Run: 01, Epoch: 77, Loss: 0.1909, Valid: 54.85%, Test: 30.13%
# Hits@50
# Run: 01, Epoch: 77, Loss: 0.1909, Valid: 63.66%, Test: 59.72%
# Hits@100
# Run: 01, Epoch: 77, Loss: 0.1909, Valid: 67.56%, Test: 79.30%
# ---
# Hits@20
# Run: 01, Epoch: 78, Loss: 0.1883, Valid: 39.30%, Test: 21.39%
# Hits@50
# Run: 01, Epoch: 78, Loss: 0.1883, Valid: 63.71%, Test: 53.03%
# Hits@100
# Run: 01, Epoch: 78, Loss: 0.1883, Valid: 67.39%, Test: 78.32%
# ---
# Hits@20
# Run: 01, Epoch: 79, Loss: 0.1879, Valid: 39.66%, Test: 16.78%
# Hits@50
# Run: 01, Epoch: 79, Loss: 0.1879, Valid: 62.99%, Test: 46.63%
# Hits@100
# Run: 01, Epoch: 79, Loss: 0.1879, Valid: 67.23%, Test: 73.72%
# ---
# Hits@20
# Run: 01, Epoch: 80, Loss: 0.1871, Valid: 52.87%, Test: 21.43%
# Hits@50
# Run: 01, Epoch: 80, Loss: 0.1871, Valid: 63.85%, Test: 67.45%
# Hits@100
# Run: 01, Epoch: 80, Loss: 0.1871, Valid: 68.02%, Test: 81.07%
# ---
# Hits@20
# Run: 01, Epoch: 81, Loss: 0.1885, Valid: 47.20%, Test: 11.80%
# Hits@50
# Run: 01, Epoch: 81, Loss: 0.1885, Valid: 62.69%, Test: 35.57%
# Hits@100
# Run: 01, Epoch: 81, Loss: 0.1885, Valid: 67.32%, Test: 57.96%
# ---
# Hits@20
# Run: 01, Epoch: 82, Loss: 0.1867, Valid: 51.30%, Test: 38.98%
# Hits@50
# Run: 01, Epoch: 82, Loss: 0.1867, Valid: 64.14%, Test: 68.58%
# Hits@100
# Run: 01, Epoch: 82, Loss: 0.1867, Valid: 67.30%, Test: 81.03%
# ---
# Hits@20
# Run: 01, Epoch: 83, Loss: 0.1851, Valid: 50.95%, Test: 15.83%
# Hits@50
# Run: 01, Epoch: 83, Loss: 0.1851, Valid: 63.47%, Test: 50.17%
# Hits@100
# Run: 01, Epoch: 83, Loss: 0.1851, Valid: 67.31%, Test: 78.10%
# ---
# Hits@20
# Run: 01, Epoch: 84, Loss: 0.1841, Valid: 55.95%, Test: 32.75%
# Hits@50
# Run: 01, Epoch: 143, Loss: 0.1625, Valid: 72.14%, Test: 90.23%
# ---
# Hits@20
# Run: 01, Epoch: 144, Loss: 0.1622, Valid: 66.27%, Test: 26.75%
# Hits@50
# Run: 01, Epoch: 144, Loss: 0.1622, Valid: 70.47%, Test: 78.39%
# Hits@100
# Run: 01, Epoch: 144, Loss: 0.1622, Valid: 72.18%, Test: 90.49%
# ---
# Hits@20
# Run: 01, Epoch: 145, Loss: 0.1610, Valid: 63.47%, Test: 29.32%
# Hits@50
# Run: 01, Epoch: 145, Loss: 0.1610, Valid: 70.15%, Test: 71.85%
# Hits@100
# Run: 01, Epoch: 145, Loss: 0.1610, Valid: 71.94%, Test: 88.61%
# ---
# Hits@20
# Run: 01, Epoch: 146, Loss: 0.1612, Valid: 66.11%, Test: 47.10%
# Hits@50
# Run: 01, Epoch: 146, Loss: 0.1612, Valid: 70.92%, Test: 82.15%
# Hits@100
# Run: 01, Epoch: 146, Loss: 0.1612, Valid: 72.30%, Test: 91.09%
# ---
# Hits@20
# Run: 01, Epoch: 147, Loss: 0.1617, Valid: 66.45%, Test: 59.02%
# Hits@50
# Run: 01, Epoch: 147, Loss: 0.1617, Valid: 70.67%, Test: 86.61%
# Hits@100
# Run: 01, Epoch: 147, Loss: 0.1617, Valid: 72.10%, Test: 92.78%
# ---
# Hits@20
# Run: 01, Epoch: 148, Loss: 0.1610, Valid: 65.40%, Test: 53.75%
# Hits@50
# Run: 01, Epoch: 148, Loss: 0.1610, Valid: 70.07%, Test: 84.25%
# Hits@100
# Run: 01, Epoch: 148, Loss: 0.1610, Valid: 71.98%, Test: 92.23%
# ---
# Hits@20
# Run: 01, Epoch: 149, Loss: 0.1608, Valid: 61.83%, Test: 46.24%
# Hits@50
# Run: 01, Epoch: 149, Loss: 0.1608, Valid: 69.92%, Test: 75.88%
# Hits@100
# Run: 01, Epoch: 149, Loss: 0.1608, Valid: 72.21%, Test: 91.25%
# ---
# Hits@20
# Run: 01, Epoch: 150, Loss: 0.1611, Valid: 66.22%, Test: 42.13%
# Hits@50
# Run: 01, Epoch: 150, Loss: 0.1611, Valid: 70.73%, Test: 78.36%
# Hits@100
# Run: 01, Epoch: 150, Loss: 0.1611, Valid: 72.42%, Test: 91.81%
# ---
# Hits@20
# Run: 01, Epoch: 151, Loss: 0.1593, Valid: 64.08%, Test: 24.59%
# Hits@50
# Run: 01, Epoch: 151, Loss: 0.1593, Valid: 70.32%, Test: 76.54%
# Hits@100
# Run: 01, Epoch: 151, Loss: 0.1593, Valid: 72.29%, Test: 91.52%
# ---
# Hits@20
# Run: 01, Epoch: 152, Loss: 0.1599, Valid: 65.95%, Test: 45.56%
# Hits@50
# Run: 01, Epoch: 152, Loss: 0.1599, Valid: 70.58%, Test: 75.95%
# Hits@100
# Run: 01, Epoch: 152, Loss: 0.1599, Valid: 72.42%, Test: 91.38%
# ---
# Hits@20
# Run: 01, Epoch: 153, Loss: 0.1601, Valid: 65.49%, Test: 30.49%
# Hits@50
# Run: 01, Epoch: 153, Loss: 0.1601, Valid: 70.83%, Test: 77.22%
# Hits@100
# Run: 01, Epoch: 153, Loss: 0.1601, Valid: 72.47%, Test: 91.76%
# ---
# Hits@20
# Run: 01, Epoch: 154, Loss: 0.1583, Valid: 64.67%, Test: 27.60%
# Hits@50
# Run: 01, Epoch: 154, Loss: 0.1583, Valid: 70.29%, Test: 73.46%
# Hits@100
# Run: 01, Epoch: 154, Loss: 0.1583, Valid: 72.47%, Test: 91.18%
# ---
# Hits@20
# Run: 01, Epoch: 155, Loss: 0.1598, Valid: 66.82%, Test: 61.29%
# Hits@50
# Run: 01, Epoch: 155, Loss: 0.1598, Valid: 70.97%, Test: 84.04%
# Hits@100
# Run: 01, Epoch: 155, Loss: 0.1598, Valid: 72.55%, Test: 92.73%
# ---
# Hits@20
# Run: 01, Epoch: 156, Loss: 0.1578, Valid: 62.01%, Test: 39.10%
# Hits@50
# Run: 01, Epoch: 156, Loss: 0.1578, Valid: 70.70%, Test: 81.09%
# Hits@100
# Run: 01, Epoch: 156, Loss: 0.1578, Valid: 72.82%, Test: 91.78%
# ---
# Hits@20
# Run: 01, Epoch: 157, Loss: 0.1574, Valid: 67.10%, Test: 48.61%
# Hits@50
# Run: 01, Epoch: 157, Loss: 0.1574, Valid: 70.72%, Test: 84.47%
# Hits@100
# Run: 01, Epoch: 157, Loss: 0.1574, Valid: 72.64%, Test: 94.28%
# ---
# Hits@20
# Run: 01, Epoch: 158, Loss: 0.1590, Valid: 66.39%, Test: 38.15%
# Hits@50
# Run: 01, Epoch: 158, Loss: 0.1590, Valid: 70.69%, Test: 80.98%
# Hits@100
# Run: 01, Epoch: 158, Loss: 0.1590, Valid: 72.40%, Test: 93.03%
# ---
# Hits@20
# Run: 01, Epoch: 159, Loss: 0.1581, Valid: 67.69%, Test: 35.93%
# Hits@50
# Run: 01, Epoch: 159, Loss: 0.1581, Valid: 70.98%, Test: 83.53%
# Hits@100
# Run: 01, Epoch: 159, Loss: 0.1581, Valid: 72.74%, Test: 92.60%
# ---
# Hits@20
# Run: 01, Epoch: 160, Loss: 0.1591, Valid: 66.15%, Test: 36.90%
# Hits@50
# Run: 01, Epoch: 160, Loss: 0.1591, Valid: 70.78%, Test: 81.08%
# Hits@100
# Run: 01, Epoch: 160, Loss: 0.1591, Valid: 72.65%, Test: 92.37%
# ---
# Hits@20
# Run: 01, Epoch: 161, Loss: 0.1576, Valid: 66.10%, Test: 58.54%
# Hits@50
# Run: 01, Epoch: 161, Loss: 0.1576, Valid: 70.50%, Test: 83.73%
# Hits@100
# Run: 01, Epoch: 161, Loss: 0.1576, Valid: 72.17%, Test: 91.46%
# ---
# Hits@20
# Run: 01, Epoch: 162, Loss: 0.1575, Valid: 66.36%, Test: 47.92%
# Hits@50
# Run: 01, Epoch: 162, Loss: 0.1575, Valid: 71.01%, Test: 83.45%
# Hits@100
# Run: 01, Epoch: 162, Loss: 0.1575, Valid: 72.59%, Test: 92.63%
# ---
# Hits@20
# Run: 01, Epoch: 163, Loss: 0.1587, Valid: 65.94%, Test: 31.01%
# Hits@50
# Run: 01, Epoch: 163, Loss: 0.1587, Valid: 71.13%, Test: 74.17%
# Hits@100
# Run: 01, Epoch: 163, Loss: 0.1587, Valid: 72.86%, Test: 92.04%
# ---
# Hits@20
# Run: 01, Epoch: 164, Loss: 0.1574, Valid: 63.82%, Test: 45.22%
# Hits@50
# Run: 01, Epoch: 164, Loss: 0.1574, Valid: 70.34%, Test: 83.05%
# Hits@100
# Run: 01, Epoch: 164, Loss: 0.1574, Valid: 72.61%, Test: 92.79%
# ---
# Hits@20
# Run: 01, Epoch: 165, Loss: 0.1578, Valid: 65.23%, Test: 43.12%
# Hits@50
# Run: 01, Epoch: 165, Loss: 0.1578, Valid: 71.25%, Test: 83.40%
# Hits@100
# Run: 01, Epoch: 165, Loss: 0.1578, Valid: 73.05%, Test: 93.34%
# ---
# Hits@20
# Run: 01, Epoch: 166, Loss: 0.1569, Valid: 66.61%, Test: 51.09%
# Hits@50
# Run: 01, Epoch: 166, Loss: 0.1569, Valid: 71.12%, Test: 84.73%
# Hits@100
# Run: 01, Epoch: 166, Loss: 0.1569, Valid: 72.98%, Test: 94.20%
# ---
# Hits@20
# Run: 01, Epoch: 167, Loss: 0.1569, Valid: 67.81%, Test: 58.44%
# Hits@50
# Run: 01, Epoch: 167, Loss: 0.1569, Valid: 71.31%, Test: 86.43%
# Hits@100
# Run: 01, Epoch: 167, Loss: 0.1569, Valid: 72.61%, Test: 93.81%
# ---
# Hits@20
# Run: 01, Epoch: 168, Loss: 0.1571, Valid: 65.08%, Test: 33.82%
# Hits@50
# Run: 01, Epoch: 168, Loss: 0.1571, Valid: 70.72%, Test: 72.85%
# Hits@100
# Run: 01, Epoch: 168, Loss: 0.1571, Valid: 72.56%, Test: 93.71%
# ---
# Hits@20
# Run: 01, Epoch: 169, Loss: 0.1562, Valid: 68.10%, Test: 41.54%
# Hits@50
# Run: 01, Epoch: 169, Loss: 0.1562, Valid: 71.28%, Test: 83.38%
# Hits@100
# Run: 01, Epoch: 169, Loss: 0.1562, Valid: 72.67%, Test: 93.54%
# ---
# Hits@20
# Run: 01, Epoch: 170, Loss: 0.1565, Valid: 67.38%, Test: 53.29%
# Hits@50
# Run: 01, Epoch: 170, Loss: 0.1565, Valid: 70.80%, Test: 83.93%
# Hits@100
# Run: 01, Epoch: 170, Loss: 0.1565, Valid: 72.46%, Test: 93.61%
# ---
# Hits@20
# Run: 01, Epoch: 171, Loss: 0.1560, Valid: 67.16%, Test: 54.85%
# Hits@50
# Run: 01, Epoch: 171, Loss: 0.1560, Valid: 71.33%, Test: 89.45%
# Hits@100
# Run: 01, Epoch: 171, Loss: 0.1560, Valid: 72.72%, Test: 94.23%
# ---
# Hits@20
# Run: 01, Epoch: 172, Loss: 0.1560, Valid: 67.43%, Test: 65.47%
# Hits@50
# Run: 01, Epoch: 172, Loss: 0.1560, Valid: 71.41%, Test: 90.16%
# Hits@100
# Run: 01, Epoch: 172, Loss: 0.1560, Valid: 72.90%, Test: 94.37%
# ---
# Hits@20
# Run: 01, Epoch: 173, Loss: 0.1558, Valid: 65.22%, Test: 45.13%
# Hits@50
# Run: 01, Epoch: 173, Loss: 0.1558, Valid: 70.96%, Test: 83.89%
# Hits@100
# Run: 01, Epoch: 173, Loss: 0.1558, Valid: 72.88%, Test: 93.86%
# ---
# Hits@20
# Run: 01, Epoch: 174, Loss: 0.1569, Valid: 65.30%, Test: 33.80%
# Hits@50
# Run: 01, Epoch: 174, Loss: 0.1569, Valid: 70.90%, Test: 83.31%
# Hits@100
# Run: 01, Epoch: 174, Loss: 0.1569, Valid: 72.88%, Test: 93.01%
# ---
# Hits@20
# Run: 01, Epoch: 175, Loss: 0.1556, Valid: 68.44%, Test: 44.81%
# Hits@50
# Run: 01, Epoch: 175, Loss: 0.1556, Valid: 71.55%, Test: 84.31%
# Hits@100
# Run: 01, Epoch: 175, Loss: 0.1556, Valid: 72.89%, Test: 94.09%
# ---
# Hits@20
# Run: 01, Epoch: 176, Loss: 0.1555, Valid: 66.29%, Test: 48.15%
# Hits@50
# Run: 01, Epoch: 176, Loss: 0.1555, Valid: 71.35%, Test: 86.78%
# Hits@100
# Run: 01, Epoch: 176, Loss: 0.1555, Valid: 72.92%, Test: 94.21%
# ---
# Hits@20
# Run: 01, Epoch: 177, Loss: 0.1559, Valid: 68.66%, Test: 44.19%
# Hits@50
# Run: 01, Epoch: 177, Loss: 0.1559, Valid: 71.79%, Test: 87.53%
# Hits@100
# Run: 01, Epoch: 177, Loss: 0.1559, Valid: 73.28%, Test: 94.68%
# ---
# Hits@20
# Run: 01, Epoch: 178, Loss: 0.1557, Valid: 67.52%, Test: 41.02%
# Hits@50
# Run: 01, Epoch: 178, Loss: 0.1557, Valid: 71.12%, Test: 82.06%
# Hits@100
# Run: 01, Epoch: 178, Loss: 0.1557, Valid: 72.81%, Test: 94.03%
# ---
# Hits@20
# Run: 01, Epoch: 179, Loss: 0.1557, Valid: 65.74%, Test: 44.76%
# Hits@50
# Run: 01, Epoch: 179, Loss: 0.1557, Valid: 71.15%, Test: 85.74%
# Hits@100
# Run: 01, Epoch: 179, Loss: 0.1557, Valid: 73.21%, Test: 94.08%
# ---
# Hits@20
# Run: 01, Epoch: 180, Loss: 0.1555, Valid: 65.39%, Test: 31.87%
# Hits@50
# Run: 01, Epoch: 180, Loss: 0.1555, Valid: 72.02%, Test: 77.38%
# Hits@100
# Run: 01, Epoch: 180, Loss: 0.1555, Valid: 73.33%, Test: 93.19%
# ---
# Hits@20
# Run: 01, Epoch: 181, Loss: 0.1541, Valid: 67.91%, Test: 41.37%
# Hits@50
# Run: 01, Epoch: 181, Loss: 0.1541, Valid: 71.44%, Test: 86.68%
# Hits@100
# Run: 01, Epoch: 181, Loss: 0.1541, Valid: 72.96%, Test: 94.46%
# ---
# Hits@20
# Run: 01, Epoch: 182, Loss: 0.1554, Valid: 67.19%, Test: 15.30%
# Hits@50
# Run: 01, Epoch: 182, Loss: 0.1554, Valid: 71.83%, Test: 69.81%
# Hits@100
# Run: 01, Epoch: 182, Loss: 0.1554, Valid: 73.11%, Test: 93.15%
# ---
# Hits@20
# Run: 01, Epoch: 183, Loss: 0.1542, Valid: 68.49%, Test: 42.23%
# Hits@50
# Run: 01, Epoch: 183, Loss: 0.1542, Valid: 71.88%, Test: 84.95%
# Hits@100
# Run: 01, Epoch: 183, Loss: 0.1542, Valid: 73.06%, Test: 94.57%
# ---
# Hits@20
# Run: 01, Epoch: 184, Loss: 0.1555, Valid: 67.24%, Test: 46.95%
# Hits@50
# Run: 01, Epoch: 184, Loss: 0.1555, Valid: 71.63%, Test: 85.37%
# Hits@100
# Run: 01, Epoch: 184, Loss: 0.1555, Valid: 73.14%, Test: 93.82%
# ---
# Hits@20
# Run: 01, Epoch: 185, Loss: 0.1529, Valid: 67.93%, Test: 50.16%
# Hits@50
# Run: 01, Epoch: 185, Loss: 0.1529, Valid: 71.60%, Test: 85.19%
# Hits@100
# Run: 01, Epoch: 185, Loss: 0.1529, Valid: 73.25%, Test: 94.46%
# ---
# Hits@20
# Run: 01, Epoch: 186, Loss: 0.1536, Valid: 68.49%, Test: 32.49%
# Hits@50
# Run: 01, Epoch: 186, Loss: 0.1536, Valid: 71.85%, Test: 80.58%
# Hits@100
# Run: 01, Epoch: 186, Loss: 0.1536, Valid: 73.22%, Test: 93.84%
# ---
# Hits@20
# Run: 01, Epoch: 187, Loss: 0.1539, Valid: 67.15%, Test: 47.94%
# Hits@50
# Run: 01, Epoch: 187, Loss: 0.1539, Valid: 71.77%, Test: 86.26%
# Hits@100
# Run: 01, Epoch: 187, Loss: 0.1539, Valid: 73.04%, Test: 92.70%
# ---
# Hits@20
# Run: 01, Epoch: 188, Loss: 0.1550, Valid: 68.87%, Test: 33.02%
# Hits@50
# Run: 01, Epoch: 188, Loss: 0.1550, Valid: 72.42%, Test: 78.22%
# Hits@100
# Run: 01, Epoch: 188, Loss: 0.1550, Valid: 73.38%, Test: 94.06%
# ---
# Hits@20
# Run: 01, Epoch: 189, Loss: 0.1539, Valid: 66.70%, Test: 42.68%
# Hits@50
# Run: 01, Epoch: 189, Loss: 0.1539, Valid: 72.15%, Test: 85.88%
# Hits@100
# Run: 01, Epoch: 189, Loss: 0.1539, Valid: 73.53%, Test: 94.13%
# ---
# Hits@20
# Run: 01, Epoch: 190, Loss: 0.1535, Valid: 67.82%, Test: 51.68%
# Hits@50
# Run: 01, Epoch: 190, Loss: 0.1535, Valid: 71.96%, Test: 87.99%
# Hits@100
# Run: 01, Epoch: 190, Loss: 0.1535, Valid: 73.34%, Test: 93.87%
# ---
# Hits@20
# Run: 01, Epoch: 191, Loss: 0.1549, Valid: 68.10%, Test: 59.91%
# Hits@50
# Run: 01, Epoch: 191, Loss: 0.1549, Valid: 71.98%, Test: 86.32%
# Hits@100
# Run: 01, Epoch: 191, Loss: 0.1549, Valid: 73.26%, Test: 94.70%
# ---
# Hits@20
# Run: 01, Epoch: 192, Loss: 0.1563, Valid: 63.45%, Test: 8.98%
# Hits@50
# Run: 01, Epoch: 192, Loss: 0.1563, Valid: 71.25%, Test: 59.94%
# Hits@100
# Run: 01, Epoch: 192, Loss: 0.1563, Valid: 73.07%, Test: 88.79%
# ---
# Hits@20
# Run: 01, Epoch: 193, Loss: 0.1543, Valid: 66.96%, Test: 18.89%
# Hits@50
# Run: 01, Epoch: 193, Loss: 0.1543, Valid: 72.07%, Test: 77.68%
# Hits@100
# Run: 01, Epoch: 193, Loss: 0.1543, Valid: 73.20%, Test: 91.91%
# ---
# Hits@20
# Run: 01, Epoch: 194, Loss: 0.1529, Valid: 66.87%, Test: 29.58%
# Hits@50
# Run: 01, Epoch: 194, Loss: 0.1529, Valid: 72.14%, Test: 80.22%
# Hits@100
# Run: 01, Epoch: 194, Loss: 0.1529, Valid: 73.20%, Test: 93.00%
# ---
# Hits@20
# Run: 01, Epoch: 195, Loss: 0.1529, Valid: 68.43%, Test: 38.19%
# Hits@50
# Run: 01, Epoch: 195, Loss: 0.1529, Valid: 72.26%, Test: 81.48%
# Hits@100
# Run: 01, Epoch: 195, Loss: 0.1529, Valid: 73.56%, Test: 94.38%
# ---
# Hits@20
# Run: 01, Epoch: 196, Loss: 0.1529, Valid: 60.71%, Test: 33.00%
# Hits@50
# Run: 01, Epoch: 196, Loss: 0.1529, Valid: 72.02%, Test: 82.25%
# Hits@100
# Run: 01, Epoch: 196, Loss: 0.1529, Valid: 73.24%, Test: 94.40%
# ---
# Hits@20
# Run: 01, Epoch: 197, Loss: 0.1531, Valid: 67.75%, Test: 25.75%
# Hits@50
# Run: 01, Epoch: 197, Loss: 0.1531, Valid: 72.32%, Test: 78.90%
# Hits@100
# Run: 01, Epoch: 197, Loss: 0.1531, Valid: 73.50%, Test: 94.33%
# ---
# Hits@20
# Run: 01, Epoch: 198, Loss: 0.1521, Valid: 68.60%, Test: 28.22%
# Hits@50
# Run: 01, Epoch: 198, Loss: 0.1521, Valid: 72.48%, Test: 87.14%
# Hits@100
# Run: 01, Epoch: 198, Loss: 0.1521, Valid: 75.15%, Test: 94.85%
# ---
# Hits@20
# Run: 01, Epoch: 199, Loss: 0.1522, Valid: 66.69%, Test: 61.68%
# Hits@50
# Run: 01, Epoch: 199, Loss: 0.1522, Valid: 72.03%, Test: 88.67%
# Hits@100
# Run: 01, Epoch: 199, Loss: 0.1522, Valid: 73.51%, Test: 95.69%
# ---
# Hits@20
# Run: 01, Epoch: 200, Loss: 0.1521, Valid: 68.85%, Test: 62.11%
# Hits@50
# Run: 01, Epoch: 200, Loss: 0.1521, Valid: 72.43%, Test: 89.48%
# Hits@100
# Run: 01, Epoch: 200, Loss: 0.1521, Valid: 73.45%, Test: 95.34%
# ---
# Hits@20
# Run 01:
# Highest Valid: 68.87
#    Final Test: 33.02
# Hits@50
# Run 01:
# Highest Valid: 72.48
#    Final Test: 87.14
# Hits@100
# Run 01:
# Highest Valid: 75.15
#    Final Test: 94.85

# %%
hits_100 = loggers["Hits@100"].results[0]
hits_50 = loggers["Hits@50"].results[0]
hits_20 = loggers["Hits@20"].results[0]

df_100 = pd.DataFrame(hits_100)
df_50 = pd.DataFrame(hits_50)
df_20 = pd.DataFrame(hits_20)

df_100.to_csv("laplacian_edge_features_hits_100.csv")
df_50.to_csv("laplacian_edge_features_hits_50.csv")
df_20.to_csv("laplacian_edge_features_hits_20.csv")
